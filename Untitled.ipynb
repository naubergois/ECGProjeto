# %%
#!pip install wfdb
# !pip install datasets
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/cd/fe/4d2874473a753d59c83335691bd9532704f2605418a0d288a1d70fa003fc/datasets-0.0.9.zip
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/wv/z16r2fpd4sl_4nbcy8s7hg700000gn/T/pip-build-GR_Wmc/datasets/setup.py", line 10, in <module>
#         with open(path.join(here, 'DESCRIPTION.rst'), encoding='utf-8') as f:
#       File "//anaconda/lib/python2.7/codecs.py", line 896, in open
#         file = __builtin__.open(filename, mode, buffering)
#     IOError: [Errno 2] No such file or directory: '/private/var/folders/wv/z16r2fpd4sl_4nbcy8s7hg700000gn/T/pip-build-GR_Wmc/datasets/DESCRIPTION.rst'
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in /private/var/folders/wv/z16r2fpd4sl_4nbcy8s7hg700000gn/T/pip-build-GR_Wmc/datasets/
# ...

# %%
import wfdb as wf
import numpy as np
from datasets import mitdb as dm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-cc0c65365d30> in <module>()
#       1 import wfdb as wf
#       2 import numpy as np
# ----> 3 from datasets import mitdb as dm
#
# ImportError: No module named datasets

# %%
import wfdb
record = wfdb.rdsamp('Dados/100', sampto=3000)
annotation = wfdb.rdann('Dados/100', 'atr', sampto=3000)

# %%
def get_records():
    """ Get paths for data in data/mit/ directory """
    # Download if doesn't exist
    if not os.path.isdir('./Dados'):
        print 'Carregando banco de dados'
        ud.download_mitdb()
        print 'Download terminado'

    # There are 3 files for each record
    # *.atr is one of them
    paths = glob('./Dados/*.atr')

    # Get rid of the extension
    paths = [path[:-4] for path in paths]
    paths.sort()

    return paths

# %%
record
# Out:
# (array([[-0.145, -0.065],
#         [-0.145, -0.065],
#         [-0.145, -0.065],
#         ...,
#         [ 0.875,  0.555],
#         [ 0.925,  0.21 ],
#         [ 0.795, -0.125]]),
#  {'base_date': None,
#   'base_time': None,
#   'comments': ['69 M 1085 1629 x1', 'Aldomet, Inderal'],
#   'fs': 360,
#   'n_sig': 2,
#   'sig_len': 3000,
#   'sig_name': ['MLII', 'V5'],
#   'units': ['mV', 'mV']})

# %%
df = pd.DataFrame(myarray)

# %%
df
# Out:
#                     0
# 0        9.931938e-59
# 1      -2.968382e+173
# 2      -8.692018e+246
# 3        9.926104e-59
# 4      -6.191460e+163
# 5      -8.681769e+246
# 6        7.707012e-59
# 7      -7.205434e+139
# 8      -3.083775e+232
# 9        8.934311e-59
# 10      -4.693879e+86
# 11     -1.092774e+218
# 12       3.224398e-59
# 13      -5.335988e+57
# 14     -9.032062e+193
# 15       2.850531e-59
# 16      -2.679963e+38
# 17     -4.888535e+174
# 18       3.223912e-59
# 19      -1.049289e+19
# 20     -5.911053e+198
# 21       2.600638e-59
# 22      -8.804695e-11
# 23      -8.105114e+63
# 24       6.775067e-60
# 25      -7.374126e-97
# 26      1.006471e-114
# 27       1.008701e+21
# 28     -3.174256e-114
# 29      -1.015032e+88
# ...               ...
# 243720   1.232255e-59
# 243721  -2.094068e-25
# 243722  -2.880073e+49
# 243723   1.731311e-59
# 243724  -8.462204e-69
# 243725 -2.759123e+102
# 243726   1.607823e-59
# 243727  -8.440858e-11
# 243728  -2.285908e+78
# ...
