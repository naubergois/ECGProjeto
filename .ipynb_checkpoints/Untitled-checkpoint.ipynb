# %%
# !pip install wfdb
# Out:
# Requirement already satisfied: wfdb in /anaconda/lib/python2.7/site-packages
# Requirement already satisfied: nose>=1.3.7 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: pandas>=0.19.1 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: sklearn>=0.0 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: numpy>=1.11.0 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: matplotlib>=1.5.1 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: requests>=2.10.0 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: scipy>=0.19.0 in /anaconda/lib/python2.7/site-packages (from wfdb)
# Requirement already satisfied: pytz>=2011k in /anaconda/lib/python2.7/site-packages (from pandas>=0.19.1->wfdb)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/naubergois/.local/lib/python2.7/site-packages (from pandas>=0.19.1->wfdb)
# Requirement already satisfied: scikit-learn in /anaconda/lib/python2.7/site-packages (from sklearn>=0.0->wfdb)
# Requirement already satisfied: cycler in /anaconda/lib/python2.7/site-packages (from matplotlib>=1.5.1->wfdb)
# Requirement already satisfied: pyparsing!=2.0.0,!=2.0.4,>=1.5.6 in /anaconda/lib/python2.7/site-packages (from matplotlib>=1.5.1->wfdb)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda/lib/python2.7/site-packages (from requests>=2.10.0->wfdb)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda/lib/python2.7/site-packages (from requests>=2.10.0->wfdb)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda/lib/python2.7/site-packages (from requests>=2.10.0->wfdb)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/lib/python2.7/site-packages (from requests>=2.10.0->wfdb)
# Requirement already satisfied: six>=1.5 in /anaconda/lib/python2.7/site-packages (from python-dateutil>=2.5.0->pandas>=0.19.1->wfdb)
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import wfdb
record = wfdb.rdsamp('mitdb/100', sampto=3000)
annotation = wfdb.rdann('sampledata/100', 'atr', sampto=3000)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-d3e3d2b91967> in <module>()
# ----> 1 import wfdb
#       2 record = wfdb.rdsamp('mitdb/100', sampto=3000)
#       3 annotation = wfdb.rdann('sampledata/100', 'atr', sampto=3000)
#
# ModuleNotFoundError: No module named 'wfdb'

# %%
import numpy as np
myarray = np.fromfile('./Dados/100.dat', dtype=float)

# %%
df = pd.DataFrame(myarray)

# %%
df
# Out:
#                     0
# 0        9.931938e-59
# 1      -2.968382e+173
# 2      -8.692018e+246
# 3        9.926104e-59
# 4      -6.191460e+163
# 5      -8.681769e+246
# 6        7.707012e-59
# 7      -7.205434e+139
# 8      -3.083775e+232
# 9        8.934311e-59
# 10      -4.693879e+86
# 11     -1.092774e+218
# 12       3.224398e-59
# 13      -5.335988e+57
# 14     -9.032062e+193
# 15       2.850531e-59
# 16      -2.679963e+38
# 17     -4.888535e+174
# 18       3.223912e-59
# 19      -1.049289e+19
# 20     -5.911053e+198
# 21       2.600638e-59
# 22      -8.804695e-11
# 23      -8.105114e+63
# 24       6.775067e-60
# 25      -7.374126e-97
# 26      1.006471e-114
# 27       1.008701e+21
# 28     -3.174256e-114
# 29      -1.015032e+88
# ...               ...
# 243720   1.232255e-59
# 243721  -2.094068e-25
# 243722  -2.880073e+49
# 243723   1.731311e-59
# 243724  -8.462204e-69
# 243725 -2.759123e+102
# 243726   1.607823e-59
# 243727  -8.440858e-11
# 243728  -2.285908e+78
# 243729   7.097157e-60
# 243730 -8.834907e-122
# 243731  -1.017929e+35
# 243732   2.473467e-60
# 243733 -1.472296e-208
# 243734  -6.664470e+39
# 243735   2.768878e-60
# 243736 -2.165430e-237
# 243737  -8.060089e+63
# 243738   3.081244e-60
# 243739 -4.505458e-247
# 243740  -2.461119e-28
# 243741   5.971725e-61
# 243742  9.365562e+143
# 243743  3.675066e-182
# 243744   1.452245e+19
# 243745 -1.065483e-301
# 243746   1.779876e+11
# 243747   8.829470e-57
# 243748  1.338439e+278
# 243749  2.114141e-307
#
# [243750 rows x 1 columns]
