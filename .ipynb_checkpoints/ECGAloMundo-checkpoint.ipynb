# %%
#!pip install wfdb
#!pip install datasets
#os.chdir('/Users/naubergois/ECGProject/')

# %%
import wfdb 
record = wfdb.rdsamp('./Dados/100')
annotation = wfdb.rdann('./Dados/100', 'atr')

# %%
normal = [100,101,103,105,106,112,113,114,115,116,117,121,122,123,201,202,205,209,213,215,219,220,222,234]
abnormal = [104,108,109,111,118,119,124,200,203,207,208,210,212,214,217,221,223,228,230,231,232]

# %%
len(record[0])
# Out:
# 650000

# %%
record
# Out:
# (array([[-0.145, -0.065],
#         [-0.145, -0.065],
#         [-0.145, -0.065],
#         ...,
#         [-0.675, -0.365],
#         [-0.765, -0.335],
#         [-1.28 ,  0.   ]]),
#  {'base_date': None,
#   'base_time': None,
#   'comments': ['69 M 1085 1629 x1', 'Aldomet, Inderal'],
#   'fs': 360,
#   'n_sig': 2,
#   'sig_len': 650000,
#   'sig_name': ['MLII', 'V5'],
#   'units': ['mV', 'mV']})

# %%
record_=record[1]

# %%
print 'Sampling frequency used for this record:', record_['fs']
# Out:
# Sampling frequency used for this record: 360

# %%
data = record[0]
print data
channel = data[:, 0]
# Out:
# [[-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]
#  ...,
#  [-0.675 -0.365]
#  [-0.765 -0.335]
#  [-1.28   0.   ]]

# %%
print data[:,1]
# Out:
# [-0.065 -0.065 -0.065 ..., -0.365 -0.335  0.   ]

# %%
from matplotlib import pyplot as plt

# %%
howmany = 2000

# %%
import numpy as np
times = np.arange(howmany, dtype = 'float') / record_['fs']
plt.plot(times, channel[ : howmany])
plt.xlabel('Time [s]')
plt.show()

# %%
def get_ecg_data(datfile): 
    ## convert .dat/q1c to numpy arrays
    recordname=os.path.basename(datfile).split(".dat")[0]
    recordpath=os.path.dirname(datfile)
    #cwd=os.getcwd()
    #os.chdir(recordpath) ## somehow it only works if you chdir. 

    
    annotation = wfdb.rdann('./Dados/'+recordname, 'atr')  
    record = wfdb.rdsamp('./Dados/'+recordname)
    
    record_=record[1]
    data = record[0]
    #print data
    channel = data[:, 0]
    
    
    #times = np.arange(howmany, dtype = 'float') / record_['fs']
    #plt.plot(times, channel[ : howmany])
    #plt.xlabel('Time [s]')
    #plt.show()
   
    return  data,annotation

# %%
def LoaddDatFiles(datfiles):  
    print "Teste"
    
    
    sinais = []
    target=[]  
        
    for datfile in datfiles:
        
        print "Carregando arquivo..... "+datfile
       
      
        x,y=get_ecg_data(datfile)
      
         

        try: 

                sinais.append(x)
                target.append(y)
       
        except NameError: 
                xx = x
                yy = y
    return sinais,target

# %%
def imprime_sinais(XX,yy):
    
    contador=0
    
    for sinal in XX:
        
        anotacoes=yy[contador]
        
        contador=contador+1
        
        print sinal
        
        
        Vctrecord=np.transpose(sinal)
        VctAnnotationHot=np.zeros( (6,len(Vctrecord[1])), dtype=np.int)
        
        
        VctAnnotations=list(zip(anotacoes.sample,anotacoes.symbol)) ## zip coordinates + annotations (N),(t) etc)
        
        for i in range(len(VctAnnotations)):
                    
                
                if VctAnnotations != 'N' :
        
                    print VctAnnotations[i]
            
                    
                
        channel = sinal[:, 0]
                    
        
        print "Canal 0"
        
        
        
        times = np.arange(howmany, dtype = 'float') / record_['fs']
        plt.plot(times, channel[ : howmany])
        plt.xlabel('Time [s]')
        plt.show()
        
        
        channel = sinal[:, 1]
        
        
        print "Canal 1"
        
        times = np.arange(howmany, dtype = 'float') / record_['fs']
        plt.plot(times, channel[ : howmany])
        plt.xlabel('Time [s]')
        plt.show()

# %%
# !pwd
# Out:
# /Users/naubergois/ECGProject

# %%
import glob, os
from os.path import basename
datfiles=glob.glob("./Dados/"+"*.dat")
perct=0.81

# %%
int(round(len(datfiles)*perct))
# Out:
# 37

# %%
datfiles
# Out:
# ['./Dados/213.dat',
#  './Dados/207.dat',
#  './Dados/212.dat',
#  './Dados/210.dat',
#  './Dados/205.dat',
#  './Dados/201.dat',
#  './Dados/215.dat',
#  './Dados/214.dat',
#  './Dados/200.dat',
#  './Dados/228.dat',
#  './Dados/202.dat',
#  './Dados/203.dat',
#  './Dados/217.dat',
#  './Dados/106.dat',
#  './Dados/112.dat',
#  './Dados/113.dat',
#  './Dados/107.dat',
#  './Dados/111.dat',
#  './Dados/105.dat',
#  './Dados/104.dat',
#  './Dados/114.dat',
#  './Dados/100.dat',
#  './Dados/101.dat',
#  './Dados/115.dat',
#  './Dados/103.dat',
#  './Dados/117.dat',
#  './Dados/116.dat',
#  './Dados/118.dat',
#  './Dados/119.dat',
#  './Dados/109.dat',
#  './Dados/121.dat',
#  './Dados/108.dat',
#  './Dados/122.dat',
#  './Dados/123.dat',
#  './Dados/232.dat',
#  './Dados/233.dat',
#  './Dados/231.dat',
#  './Dados/219.dat',
#  './Dados/230.dat',
#  './Dados/208.dat',
#  './Dados/220.dat',
#  './Dados/234.dat',
#  './Dados/221.dat',
#  './Dados/209.dat',
#  './Dados/223.dat',
#  './Dados/222.dat']

# %%
xxt,yyt=LoaddDatFiles(datfiles[ :int(round(len(datfiles)*perct))]) # training data.
# Out:
# Teste
# Carregando arquivo..... ./Dados/213.dat
# Carregando arquivo..... ./Dados/207.dat
# Carregando arquivo..... ./Dados/212.dat
# Carregando arquivo..... ./Dados/210.dat
# Carregando arquivo..... ./Dados/205.dat
# Carregando arquivo..... ./Dados/201.dat
# Carregando arquivo..... ./Dados/215.dat
# Carregando arquivo..... ./Dados/214.dat
# Carregando arquivo..... ./Dados/200.dat
# Carregando arquivo..... ./Dados/228.dat
# Carregando arquivo..... ./Dados/202.dat
# Carregando arquivo..... ./Dados/203.dat
# Carregando arquivo..... ./Dados/217.dat
# Carregando arquivo..... ./Dados/106.dat
# Carregando arquivo..... ./Dados/112.dat
# Carregando arquivo..... ./Dados/113.dat
# Carregando arquivo..... ./Dados/107.dat
# Carregando arquivo..... ./Dados/111.dat
# Carregando arquivo..... ./Dados/105.dat
# Carregando arquivo..... ./Dados/104.dat
# Carregando arquivo..... ./Dados/114.dat
# Carregando arquivo..... ./Dados/100.dat
# Carregando arquivo..... ./Dados/101.dat
# Carregando arquivo..... ./Dados/115.dat
# Carregando arquivo..... ./Dados/103.dat
# Carregando arquivo..... ./Dados/117.dat
# Carregando arquivo..... ./Dados/116.dat
# Carregando arquivo..... ./Dados/118.dat
# Carregando arquivo..... ./Dados/119.dat
# Carregando arquivo..... ./Dados/109.dat
# Carregando arquivo..... ./Dados/121.dat
# Carregando arquivo..... ./Dados/108.dat
# Carregando arquivo..... ./Dados/122.dat
# Carregando arquivo..... ./Dados/123.dat
# Carregando arquivo..... ./Dados/232.dat
# Carregando arquivo..... ./Dados/233.dat
# Carregando arquivo..... ./Dados/231.dat

# %%
xxt
# Out:
# [array([[-0.01 , -0.615],
#         [-0.01 , -0.615],
#         [-0.01 , -0.615],
#         ...,
#         [ 1.135, -1.49 ],
#         [ 0.715, -1.345],
#         [ 1.28 , -1.28 ]]), array([[-0.215,  0.095],
#         [-0.215,  0.095],
#         [-0.215,  0.095],
#         ...,
#         [-1.19 , -0.465],
#         [-1.135, -0.4  ],
#         [-1.28 ,  0.   ]]), array([[-0.5  ,  0.05 ],
#         [-0.5  ,  0.05 ],
#         [-0.5  ,  0.05 ],
#         ...,
#         [-0.34 ,  0.235],
#         [-0.33 ,  0.22 ],
#         [ 0.   ,  0.   ]]), array([[-0.065,  0.135],
#         [-0.065,  0.135],
#         [-0.065,  0.135],
#         ...,
#         [-0.305,  0.075],
#         [-0.3  ,  0.1  ],
#         [ 0.   ,  0.   ]]), array([[-0.43 , -0.54 ],
#         [-0.43 , -0.54 ],
#         [-0.43 , -0.54 ],
#         ...,
#         [-0.365, -0.365],
#         [-0.375, -0.38 ],
#         [ 0.   ,  0.   ]]), array([[-0.26 , -0.21 ],
#         [-0.26 , -0.21 ],
#         [-0.26 , -0.21 ],
#         ...,
#         [-0.17 , -0.055],
#         [-0.18 , -0.065],
#         [ 0.   ,  0.   ]]), array([[ 0.22 ,  0.185],
#         [ 0.22 ,  0.185],
#         [ 0.22 ,  0.185],
#         ...,
#         [-0.285,  0.17 ],
#         [-0.28 ,  0.135],
#         [ 0.   ,  0.   ]]), array([[-0.095,  0.025],
#         [-0.095,  0.025],
#         [-0.095,  0.025],
#         ...,
#         [-0.32 ,  0.265],
#         [-0.285,  0.245],
#         [ 0.   ,  0.   ]]), array([[ 0.35 ,  0.105],
#         [ 0.35 ,  0.105],
#         [ 0.35 ,  0.105],
#         ...,
#         [ 0.015, -0.27 ],
#         [ 0.015, -0.27 ],
#         [ 0.   ,  0.   ]]), array([[-0.155, -0.095],
#         [-0.155, -0.095],
#         [-0.155, -0.095],
#         ...,
#         [-0.29 , -0.11 ],
#         [-0.285, -0.115],
#         [ 0.   ,  0.   ]]), array([[ 0.   ,  0.125],
#         [ 0.   ,  0.125],
#         [ 0.   ,  0.125],
#         ...,
#         [-0.24 ,  0.1  ],
#         [-0.24 ,  0.11 ],
#         [ 0.   ,  0.   ]]), array([[-0.26 ,  0.065],
#         [-0.26 ,  0.065],
#         [-0.26 ,  0.065],
#         ...,
#         [-0.55 ,  0.33 ],
#         [-0.52 ,  0.325],
#         [ 0.   ,  0.   ]]), array([[ 0.045, -0.76 ],
#         [ 0.045, -0.76 ],
#         [ 0.045, -0.76 ],
#         ...,
#         [-0.36 ,  0.14 ],
#         [-0.33 ,  0.16 ],
#         [ 0.   ,  0.   ]]), array([[-0.31 ,  0.195],
#         [-0.31 ,  0.195],
#         [-0.31 ,  0.195],
#         ...,
#         [ 0.635,  0.265],
#         [ 0.265,  0.405],
#         [ 0.   ,  0.   ]]), array([[-0.75 , -0.62 ],
#         [-0.75 , -0.62 ],
#         [-0.75 , -0.62 ],
#         ...,
#         [-0.825, -0.59 ],
#         [-0.81 , -0.58 ],
#         [-1.28 ,  0.   ]]), array([[-0.46,  0.13],
#         [-0.46,  0.13],
#         [-0.46,  0.13],
#         ...,
#         [ 1.06,  0.03],
#         [ 0.42,  0.03],
#         [ 0.  ,  0.  ]]), array([[-2.045, -1.245],
#         [-2.045, -1.245],
#         [-2.045, -1.245],
#         ...,
#         [-0.645,  0.07 ],
#         [-0.635,  0.065],
#         [ 0.   ,  0.   ]]), array([[-0.035,  0.035],
#         [-0.035,  0.035],
#         [-0.035,  0.035],
#         ...,
#         [ 0.155, -0.79 ],
#         [ 0.2  , -0.795],
#         [ 0.   , -1.28 ]]), array([[-0.445,  0.26 ],
#         [-0.445,  0.26 ],
#         [-0.445,  0.26 ],
#         ...,
#         [ 0.59 , -0.37 ],
#         [ 0.76 , -0.38 ],
#         [ 1.28 ,  0.   ]]), array([[-0.15 ,  0.2  ],
#         [-0.15 ,  0.2  ],
#         [-0.15 ,  0.2  ],
#         ...,
#         [-0.065,  0.2  ],
#         [-0.06 ,  0.205],
#         [ 0.   ,  0.   ]]), array([[-0.045,  0.015],
#         [-0.045,  0.015],
#         [-0.045,  0.015],
#         ...,
#         [-0.365, -0.215],
#         [-0.37 , -0.225],
#         [ 0.   ,  0.   ]]), array([[-0.145, -0.065],
#         [-0.145, -0.065],
#         [-0.145, -0.065],
#         ...,
#         [-0.675, -0.365],
#         [-0.765, -0.335],
#         [-1.28 ,  0.   ]]), array([[-0.345, -0.16 ],
#         [-0.345, -0.16 ],
#         [-0.345, -0.16 ],
#         ...,
#         [-0.295, -0.11 ],
#         [-0.29 , -0.11 ],
#         [ 0.   ,  0.   ]]), array([[-0.58 , -0.335],
#         [-0.58 , -0.335],
#         [-0.58 , -0.335],
#         ...,
#         [-0.75 ,  0.24 ],
#         [-0.75 ,  0.24 ],
#         [-1.28 ,  0.   ]]), array([[-0.375,  0.05 ],
#         [-0.375,  0.05 ],
#         [-0.375,  0.05 ],
#         ...,
#         [-0.235,  0.05 ],
#         [-0.245,  0.055],
#         [ 0.   ,  0.   ]]), array([[-0.925, -0.47 ],
#         [-0.925, -0.47 ],
#         [-0.925, -0.47 ],
#         ...,
#         [-0.585, -0.225],
#         [-0.565, -0.245],
#         [ 0.   ,  0.   ]]), array([[-0.32 , -1.24 ],
#         [-0.32 , -1.24 ],
#         [-0.32 , -1.24 ],
#         ...,
#         [-0.975, -0.715],
#         [-0.96 , -0.715],
#         [-1.28 , -1.28 ]]), array([[-0.835, -0.515],
#         [-0.835, -0.515],
#         [-0.835, -0.515],
#         ...,
#         [ 0.03 , -2.1  ],
#         [ 0.085, -2.14 ],
#         [ 0.   , -2.56 ]]), array([[-0.995, -0.47 ],
#         [-0.995, -0.47 ],
#         [-0.995, -0.47 ],
#         ...,
#         [ 1.565, -1.825],
#         [ 1.525, -1.74 ],
#         [ 1.28 , -1.28 ]]), array([[ 0.175,  0.635],
#         [ 0.175,  0.635],
#         [ 0.175,  0.635],
#         ...,
#         [-0.92 ,  0.36 ],
#         [-0.91 ,  0.365],
#         [-1.28 ,  0.   ]]), array([[-0.875, -0.65 ],
#         [-0.875, -0.65 ],
#         [-0.875, -0.65 ],
#         ...,
#         [-0.86 , -0.695],
#         [-0.875, -0.665],
#         [-1.28 , -1.28 ]]), array([[-0.125, -0.78 ],
#         [-0.125, -0.78 ],
#         [-0.125, -0.78 ],
#         ...,
#         [-0.01 ,  0.085],
#         [ 0.04 ,  0.08 ],
#         [ 0.   ,  0.   ]]), array([[-0.78 , -0.735],
#         [-0.78 , -0.735],
#         [-0.78 , -0.735],
#         ...,
#         [-1.02 , -0.58 ],
#         [-1.04 , -0.585],
#         [-1.28 ,  0.   ]]), array([[-0.805, -0.455],
#         [-0.805, -0.455],
#         [-0.805, -0.455],
#         ...,
#         [-1.25 , -0.705],
#         [-1.225, -0.69 ],
#         [-1.28 , -1.28 ]]), array([[-0.245,  0.21 ],
#         [-0.245,  0.21 ],
#         [-0.245,  0.21 ],
#         ...,
#         [-0.07 ,  0.015],
#         [-0.075,  0.035],
#         [ 0.   ,  0.   ]]), array([[-0.095,  0.01 ],
#         [-0.095,  0.01 ],
#         [-0.095,  0.01 ],
#         ...,
#         [-0.495,  0.32 ],
#         [-0.49 ,  0.34 ],
#         [ 0.   ,  0.   ]]), array([[-0.2  ,  0.075],
#         [-0.2  ,  0.075],
#         [-0.2  ,  0.075],
#         ...,
#         [ 0.34 , -0.195],
#         [ 0.34 , -0.19 ],
#         [ 0.   ,  0.   ]])]

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
imprime_sinais(xxt,yyt)
# Out:
# <style>.container { width:100% !important; }</style>
# [[-0.01  -0.615]
#  [-0.01  -0.615]
#  [-0.01  -0.615]
#  ...,
#  [ 1.135 -1.49 ]
#  [ 0.715 -1.345]
#  [ 1.28  -1.28 ]]
# (18, '+')
# (95, 'N')
# (253, 'N')
# (478, 'N')
# (673, 'N')
# (873, 'N')
# (1076, 'N')
# (1272, 'N')
# (1466, 'N')
# (1655, 'N')
# (1849, 'N')
# (2047, 'N')
# (2236, 'N')
# (2433, 'N')
# (2632, 'N')
# (2832, 'N')
# (3021, 'N')
# (3219, 'N')
# (3408, 'N')
# (3603, 'N')
# (3806, 'N')
# (4007, 'N')
# (4200, 'N')
# (4401, 'N')
# (4592, 'N')
# (4785, 'N')
# (4976, 'N')
# (5172, 'N')
# (5374, 'N')
# (5571, 'N')
# (5771, 'N')
# (5963, 'N')
# (6156, 'N')
# (6347, 'N')
# (6543, 'N')
# (6742, 'N')
# (6941, 'N')
# (7134, 'N')
# (7333, 'N')
# (7522, 'N')
# (7715, 'N')
# (7914, 'N')
# (8107, 'N')
# (8302, 'N')
# (8497, 'N')
# (8699, 'N')
# (8898, 'N')
# (9095, 'N')
# (9284, 'N')
# (9481, 'N')
# (9681, 'N')
# (9882, 'N')
# (10074, 'N')
# (10273, 'N')
# (10462, 'N')
# (10656, 'N')
# (10850, 'N')
# (11042, 'N')
# (11236, 'N')
# (11433, 'N')
# (11636, 'N')
# (11827, 'N')
# (12021, 'N')
# (12214, 'N')
# (12409, 'N')
# (12606, 'N')
# (12808, 'N')
# (13005, 'N')
# (13203, 'N')
# (13391, 'N')
# (13585, 'N')
# (13781, 'N')
# (13978, 'N')
# (14173, 'N')
# (14369, 'N')
# (14568, 'N')
# (14763, 'N')
# (14957, 'N')
# (15146, 'N')
# (15339, 'N')
# (15536, 'N')
# (15736, 'N')
# (15929, 'N')
# (16127, 'N')
# (16320, 'N')
# (16512, 'N')
# (16706, 'N')
# (16905, 'N')
# (17095, 'N')
# (17296, 'N')
# (17499, 'N')
# (17695, 'N')
# (17886, 'N')
# (18080, 'N')
# (18272, 'N')
# (18471, 'N')
# (18671, 'N')
# (18866, 'N')
# (19061, 'N')
# (19253, 'N')
# (19446, 'N')
# (19636, 'N')
# (19834, 'N')
# (20026, 'N')
# (20222, 'N')
# (20418, 'N')
# (20615, 'N')
# (20809, 'N')
# (21004, 'N')
# (21192, 'N')
# (21387, 'N')
# (21591, 'N')
# (21791, 'F')
# (21990, 'N')
# (22184, 'N')
# (22374, 'N')
# (22571, 'N')
# (22728, 'A')
# (22953, 'N')
# (23154, 'N')
# (23350, 'N')
# (23554, 'N')
# (23744, 'N')
# (23936, 'N')
# (24127, 'N')
# (24328, 'N')
# (24526, 'N')
# (24725, 'N')
# (24920, 'N')
# (25116, 'N')
# (25305, 'N')
# (25498, 'N')
# (25696, 'N')
# (25894, 'N')
# (26092, 'N')
# (26288, 'N')
# (26486, 'N')
# (26680, 'N')
# (26881, 'N')
# (27069, 'N')
# (27262, 'N')
# (27461, 'N')
# (27662, 'N')
# (27855, 'N')
# (28050, 'N')
# (28241, 'N')
# (28435, 'N')
# (28629, 'N')
# (28825, 'N')
# (29020, 'N')
# (29216, 'N')
# (29417, 'N')
# (29617, 'N')
# (29813, 'N')
# (30006, 'N')
# (30206, 'N')
# (30406, 'N')
# (30610, 'N')
# (30801, 'N')
# (31003, 'N')
# (31194, 'N')
# (31389, 'N')
# (31586, 'N')
# (31782, 'N')
# (31977, 'N')
# (32177, 'N')
# (32378, 'N')
# (32569, 'N')
# (32764, 'N')
# (32960, 'N')
# (33153, 'N')
# (33348, 'N')
# (33549, 'N')
# (33748, 'N')
# (33945, 'N')
# (34135, 'N')
# (34334, 'N')
# (34530, 'N')
# (34727, 'N')
# (34927, 'N')
# (35123, 'N')
# (35323, 'N')
# (35522, 'N')
# (35720, 'N')
# (35912, 'N')
# (36105, 'N')
# (36304, 'N')
# (36506, 'N')
# (36697, 'N')
# (36899, 'N')
# (37087, 'N')
# (37283, 'N')
# (37477, 'N')
# (37676, 'N')
# (37871, 'N')
# (38069, 'N')
# (38267, 'N')
# (38466, 'N')
# (38661, 'N')
# (38856, 'N')
# (39049, 'N')
# (39249, 'N')
# (39447, 'N')
# (39643, 'N')
# (39843, 'F')
# (40036, 'N')
# (40230, 'N')
# (40421, 'N')
# (40621, 'N')
# (40811, 'N')
# (41006, 'N')
# (41206, 'N')
# (41402, 'N')
# (41595, 'N')
# (41790, 'N')
# (41981, 'N')
# (42178, 'N')
# (42380, 'N')
# (42582, 'F')
# (42777, 'N')
# (42969, 'F')
# (43165, 'N')
# (43362, 'F')
# (43560, 'N')
# (43751, 'V')
# (43953, 'N')
# (44159, 'F')
# (44355, 'N')
# (44550, 'F')
# (44747, 'N')
# (44939, 'F')
# (45135, 'N')
# (45333, 'N')
# (45530, 'N')
# (45729, 'F')
# (45921, 'N')
# (46122, 'F')
# (46306, 'N')
# (46507, 'F')
# (46701, 'N')
# (46904, 'F')
# (47101, 'N')
# (47296, 'F')
# (47489, 'N')
# (47683, 'F')
# (47876, 'N')
# (48073, 'F')
# (48270, 'N')
# (48469, 'F')
# (48666, 'N')
# (48861, 'F')
# (49052, 'N')
# (49243, 'F')
# (49444, 'N')
# (49631, 'F')
# (49831, 'N')
# (49998, 'V')
# (50232, 'N')
# (50423, 'F')
# (50618, 'N')
# (50815, 'F')
# (51010, 'N')
# (51210, 'F')
# (51409, 'N')
# (51604, 'N')
# (51800, 'N')
# (51994, 'N')
# (52189, 'N')
# (52384, 'N')
# (52574, 'N')
# (52776, 'N')
# (52973, 'N')
# (53173, 'F')
# (53362, 'N')
# (53560, 'F')
# (53750, 'N')
# (53845, '+')
# (53940, 'V')
# (54141, 'N')
# (54341, 'V')
# (54535, 'N')
# (54720, 'V')
# (54821, '+')
# (54923, 'N')
# (55114, 'F')
# (55310, 'N')
# (55505, 'N')
# (55701, 'N')
# (55894, 'F')
# (56098, 'N')
# (56290, 'F')
# (56484, 'N')
# (56676, 'F')
# (56870, 'N')
# (57069, 'F')
# (57268, 'N')
# (57445, 'V')
# (57659, 'N')
# (57848, 'F')
# (58040, 'N')
# (58238, 'F')
# (58426, 'N')
# (58625, 'F')
# (58822, 'N')
# (59024, 'F')
# (59212, 'N')
# (59408, 'F')
# (59602, 'N')
# (59796, 'F')
# (59995, 'N')
# (60165, 'V')
# (60396, 'N')
# (60594, 'V')
# (60784, 'N')
# (60982, 'F')
# (61176, 'N')
# (61371, 'F')
# (61569, 'N')
# (61767, 'N')
# (61966, 'N')
# (62158, 'N')
# (62355, 'N')
# (62548, 'N')
# (62742, 'N')
# (62939, 'F')
# (63142, 'N')
# (63318, 'V')
# (63537, 'N')
# (63727, 'N')
# (63921, 'N')
# (64118, 'F')
# (64310, 'N')
# (64503, 'F')
# (64706, 'N')
# (64906, 'F')
# (65101, 'N')
# (65296, 'F')
# (65487, 'N')
# (65685, 'F')
# (65884, 'N')
# (66084, 'F')
# (66279, 'N')
# (66479, 'N')
# (66666, 'N')
# (66860, 'N')
# (67050, 'N')
# (67243, 'F')
# (67438, 'N')
# (67635, 'V')
# (67833, 'N')
# (68030, 'V')
# (68230, 'N')
# (68422, 'F')
# (68614, 'N')
# (68815, 'F')
# (69020, 'N')
# (69215, 'F')
# (69411, 'N')
# (69603, 'F')
# (69804, 'N')
# (69999, 'N')
# (70194, 'N')
# (70388, 'N')
# (70590, 'N')
# (70787, 'F')
# (70985, 'N')
# (71178, 'V')
# (71371, 'N')
# (71534, 'V')
# (71764, 'N')
# (71965, 'F')
# (72160, 'N')
# (72362, 'F')
# (72555, 'N')
# (72748, 'F')
# (72942, 'N')
# (73141, 'F')
# (73335, 'N')
# (73536, 'F')
# (73737, 'N')
# (73938, 'F')
# (74131, 'N')
# (74330, 'F')
# (74526, 'N')
# (74721, 'F')
# (74923, 'N')
# (75122, 'F')
# (75322, 'N')
# (75512, 'F')
# (75703, 'N')
# (75896, 'V')
# (76100, 'N')
# (76291, 'F')
# (76488, 'N')
# (76687, 'N')
# (76884, 'N')
# (77075, 'N')
# (77274, 'N')
# (77464, 'F')
# (77661, 'N')
# (77867, 'V')
# (78064, 'N')
# (78258, 'F')
# (78456, 'N')
# (78654, 'F')
# (78845, 'N')
# (79043, 'F')
# (79238, 'N')
# (79436, 'F')
# (79632, 'N')
# (79830, 'F')
# (80023, 'N')
# (80218, 'F')
# (80410, 'N')
# (80606, 'F')
# (80802, 'N')
# (81004, 'F')
# (81189, 'F')
# (81394, 'N')
# (81585, 'N')
# (81781, 'N')
# (81981, 'N')
# (82179, 'F')
# (82382, 'N')
# (82579, 'F')
# (82779, 'N')
# (82976, 'F')
# (83170, 'N')
# (83359, 'F')
# (83559, 'N')
# (83758, 'F')
# (83957, 'N')
# (84153, 'F')
# (84350, 'N')
# (84539, 'F')
# (84734, 'N')
# (84933, 'F')
# (85123, 'N')
# (85324, 'F')
# (85524, 'N')
# (85722, 'N')
# (85914, 'N')
# (86113, 'N')
# (86306, 'N')
# (86503, 'N')
# (86707, 'N')
# (86907, 'F')
# (87101, 'N')
# (87301, 'V')
# (87442, 'N')
# (87675, 'F')
# (87884, 'N')
# (88078, 'N')
# (88275, 'N')
# (88468, 'N')
# (88668, 'N')
# (88859, 'N')
# (89051, 'N')
# (89240, 'F')
# (89437, 'N')
# (89637, 'F')
# (89838, 'N')
# (90032, 'V')
# (90231, 'N')
# (90423, 'N')
# (90620, 'N')
# (90822, 'N')
# (91010, 'N')
# (91210, 'N')
# (91410, 'N')
# (91615, 'N')
# (91806, 'N')
# (92003, 'F')
# (92201, 'N')
# (92397, 'F')
# (92591, 'N')
# (92788, 'F')
# (92983, 'N')
# (93152, 'V')
# (93381, 'N')
# (93571, 'N')
# (93768, 'N')
# (93964, 'N')
# (94167, 'N')
# (94362, 'N')
# (94561, 'N')
# (94753, 'N')
# (94952, 'N')
# (95145, 'N')
# (95340, 'N')
# (95537, 'N')
# (95734, 'N')
# (95831, '+')
# (95929, 'V')
# (96127, 'N')
# (96314, 'V')
# (96508, 'N')
# (96688, 'V')
# (96794, '+')
# (96900, 'N')
# (97094, 'F')
# (97286, 'N')
# (97491, 'N')
# (97681, 'N')
# (97874, 'F')
# (98068, 'N')
# (98264, 'N')
# (98463, 'N')
# (98663, 'N')
# (98858, 'N')
# (99059, 'N')
# (99250, 'N')
# (99445, 'F')
# (99646, 'N')
# (99823, 'V')
# (100036, 'N')
# (100236, 'N')
# (100436, 'N')
# (100637, 'N')
# (100833, 'N')
# (101024, 'N')
# (101218, 'N')
# (101418, 'N')
# (101618, 'N')
# (101811, 'F')
# (102009, 'N')
# (102185, 'V')
# (102398, 'N')
# (102596, 'N')
# (102791, 'N')
# (102993, 'N')
# (103189, 'N')
# (103392, 'N')
# (103587, 'N')
# (103789, 'N')
# (103977, 'N')
# (104173, 'N')
# (104373, 'N')
# (104583, 'N')
# (104776, 'N')
# (104974, 'N')
# (105166, 'N')
# (105365, 'N')
# (105558, 'N')
# (105750, 'F')
# (105950, 'N')
# (106131, 'V')
# (106350, 'N')
# (106527, 'V')
# (106741, 'N')
# (106940, 'F')
# (107133, 'N')
# (107329, 'N')
# (107533, 'N')
# (107730, 'N')
# (107929, 'N')
# (108119, 'F')
# (108317, 'N')
# (108512, 'V')
# (108707, 'N')
# (108908, 'V')
# (109103, 'N')
# (109303, 'N')
# (109499, 'N')
# (109696, 'N')
# (109885, 'N')
# (110076, 'N')
# (110278, 'N')
# (110480, 'N')
# (110672, 'N')
# (110873, 'N')
# (111062, 'N')
# (111258, 'N')
# (111451, 'N')
# (111630, 'V')
# (111846, 'N')
# (112028, 'V')
# (112251, 'N')
# (112449, 'N')
# (112646, 'N')
# (112845, 'N')
# (113037, 'N')
# (113234, 'N')
# (113437, 'N')
# (113631, 'N')
# (113827, 'N')
# (114019, 'N')
# (114211, 'N')
# (114401, 'N')
# (114596, 'N')
# (114696, '+')
# (114796, 'V')
# (114993, 'N')
# (115191, 'V')
# (115390, 'N')
# (115590, 'V')
# (115686, '+')
# (115782, 'N')
# (115973, 'N')
# (116175, 'N')
# (116377, 'N')
# (116575, 'N')
# (116774, 'N')
# (116967, 'N')
# (117159, 'F')
# (117352, 'N')
# (117520, 'V')
# (117746, 'N')
# (117945, 'V')
# (118148, 'N')
# (118344, 'N')
# (118536, 'N')
# (118730, 'N')
# (118924, 'N')
# (119120, 'N')
# (119320, 'N')
# (119515, 'N')
# (119717, 'N')
# (119908, 'N')
# (120102, 'N')
# (120295, 'F')
# (120498, 'N')
# (120663, 'V')
# (120897, 'N')
# (121097, 'N')
# (121299, 'N')
# (121493, 'N')
# (121687, 'N')
# (121883, 'N')
# (122083, 'N')
# (122282, 'N')
# (122480, 'N')
# (122682, 'N')
# (122872, 'N')
# (123066, 'N')
# (123216, 'A')
# (123455, 'N')
# (123649, 'N')
# (123849, 'N')
# (124053, 'N')
# (124250, 'N')
# (124444, 'N')
# (124641, 'N')
# (124834, 'N')
# (124998, 'A')
# (125237, 'N')
# (125439, 'N')
# (125635, 'N')
# (125829, 'N')
# (126024, 'N')
# (126223, 'N')
# (126420, 'N')
# (126615, 'N')
# (126817, 'N')
# (127019, 'N')
# (127213, 'N')
# (127405, 'N')
# (127603, 'N')
# (127794, 'N')
# (127991, 'N')
# (128197, 'N')
# (128396, 'N')
# (128593, 'N')
# (128784, 'N')
# (128981, 'N')
# (129181, 'N')
# (129378, 'N')
# (129520, 'A')
# (129764, 'N')
# (129971, 'N')
# (130166, 'N')
# (130361, 'N')
# (130557, 'N')
# (130748, 'N')
# (130948, 'N')
# (131153, 'N')
# (131350, 'N')
# (131544, 'N')
# (131734, 'N')
# (131932, 'N')
# (132123, 'N')
# (132321, 'N')
# (132518, 'N')
# (132715, 'N')
# (132916, 'N')
# (133114, 'N')
# (133307, 'N')
# (133503, 'N')
# (133697, 'N')
# (133902, 'N')
# (134101, 'N')
# (134296, 'N')
# (134453, 'A')
# (134688, 'N')
# (134888, 'N')
# (135082, 'N')
# (135282, 'N')
# (135475, 'N')
# (135625, 'A')
# (135868, 'N')
# (136065, 'N')
# (136260, 'N')
# (136453, 'N')
# (136648, 'N')
# (136851, 'N')
# (137050, 'N')
# (137246, 'N')
# (137443, 'N')
# (137636, 'N')
# (137831, 'N')
# (138023, 'N')
# (138224, 'N')
# (138418, 'N')
# (138616, 'N')
# (138821, 'N')
# (139016, 'N')
# (139210, 'N')
# (139403, 'N')
# (139599, 'N')
# (139804, 'N')
# (140004, 'N')
# (140198, 'N')
# (140400, 'N')
# (140591, 'N')
# (140786, 'N')
# (140981, 'N')
# (141181, 'N')
# (141374, 'N')
# (141574, 'N')
# (141776, 'N')
# (141970, 'N')
# (142168, 'N')
# (142368, 'N')
# (142561, 'N')
# (142759, 'N')
# (142923, 'A')
# (143162, 'N')
# (143362, 'N')
# (143557, 'N')
# (143752, 'N')
# (143949, 'N')
# (144146, 'N')
# (144343, 'N')
# (144539, 'N')
# (144737, 'N')
# (144936, 'N')
# (145133, 'N')
# (145322, 'N')
# (145516, 'N')
# (145714, 'N')
# (145923, 'N')
# (146116, 'N')
# (146314, 'N')
# (146502, 'N')
# (146710, 'N')
# (146903, 'N')
# (147100, 'N')
# (147299, 'N')
# (147501, 'N')
# (147697, 'N')
# (147892, 'N')
# (148087, 'N')
# (148288, 'N')
# (148479, 'N')
# (148676, 'N')
# (148880, 'N')
# (149076, 'N')
# (149280, 'N')
# (149467, 'N')
# (149659, 'N')
# (149856, 'N')
# (150053, 'N')
# (150246, 'N')
# (150442, 'N')
# (150645, 'N')
# (150839, 'N')
# (151035, 'N')
# (151232, 'N')
# (151429, 'N')
# (151627, 'N')
# (151830, 'N')
# (152030, 'N')
# (152227, 'N')
# (152417, 'N')
# (152615, 'N')
# (152813, 'N')
# (153007, 'N')
# (153199, 'N')
# (153399, 'N')
# (153599, 'N')
# (153793, 'N')
# (153987, 'N')
# (154187, 'N')
# (154379, 'N')
# (154575, 'N')
# (154779, 'N')
# (154980, 'N')
# (155175, 'N')
# (155369, 'N')
# (155569, 'N')
# (155761, 'N')
# (155958, 'F')
# (156155, 'N')
# (156357, 'N')
# (156556, 'N')
# (156753, 'N')
# (156951, 'N')
# (157147, 'N')
# (157334, 'N')
# (157530, 'N')
# (157732, 'N')
# (157933, 'N')
# (158126, 'N')
# (158289, 'A')
# (158511, 'N')
# (158710, 'N')
# (158907, 'N')
# (159096, 'N')
# (159294, 'N')
# (159494, 'N')
# (159674, 'V')
# (159891, 'N')
# (160086, 'N')
# (160282, 'N')
# (160479, 'N')
# (160678, 'N')
# (160877, 'N')
# (161075, 'N')
# (161268, 'N')
# (161459, 'N')
# (161653, 'N')
# (161850, 'N')
# (162039, 'F')
# (162239, 'N')
# (162438, 'V')
# (162636, 'N')
# (162827, 'V')
# (163026, 'N')
# (163222, 'F')
# (163414, 'N')
# (163614, 'F')
# (163818, 'N')
# (164017, 'F')
# (164212, 'N')
# (164405, 'F')
# (164607, 'N')
# (164805, 'F')
# (164996, 'N')
# (165201, 'V')
# (165397, 'N')
# (165595, 'V')
# (165796, 'N')
# (165991, 'F')
# (166180, 'N')
# (166376, 'F')
# (166586, 'N')
# (166782, 'F')
# (166981, 'N')
# (167075, '+')
# (167169, 'V')
# (167372, 'N')
# (167547, 'V')
# (167763, 'N')
# (167961, 'V')
# (168060, '+')
# (168160, 'N')
# (168359, 'F')
# (168563, 'N')
# (168759, 'F')
# (168951, 'N')
# (169143, 'V')
# (169338, 'N')
# (169547, 'N')
# (169749, 'N')
# (169946, 'V')
# (170139, 'N')
# (170336, 'F')
# (170527, 'N')
# (170619, '+')
# (170712, 'V')
# (170924, 'N')
# (171123, 'V')
# (171322, 'N')
# (171520, 'V')
# (171620, '+')
# (171721, 'N')
# (171915, 'F')
# (172103, 'N')
# (172306, 'F')
# (172515, 'N')
# (172715, 'F')
# (172912, 'N')
# (173108, 'F')
# (173305, 'N')
# (173400, '+')
# (173495, 'V')
# (173700, 'N')
# (173896, 'V')
# (174095, 'N')
# (174268, 'V')
# (174382, '+')
# (174497, 'N')
# (174691, 'N')
# (174883, 'N')
# (175079, 'N')
# (175284, 'N')
# (175484, 'F')
# (175683, 'N')
# (175883, 'F')
# (176074, 'N')
# (176272, 'F')
# (176464, 'N')
# (176557, '+')
# (176651, 'V')
# (176863, 'N')
# (177029, 'V')
# (177268, 'N')
# (177450, 'V')
# (177558, '+')
# (177666, 'N')
# (177860, 'F')
# (178052, 'N')
# (178253, 'F')
# (178458, 'N')
# (178656, 'F')
# (178849, 'N')
# (179040, 'F')
# (179235, 'N')
# (179432, 'F')
# (179625, 'N')
# (179820, 'V')
# (180019, 'N')
# (180193, 'V')
# (180416, 'N')
# (180612, 'F')
# (180808, 'N')
# (181004, 'N')
# (181204, 'N')
# (181407, 'N')
# (181602, 'N')
# (181807, 'N')
# (181997, 'N')
# (182189, 'V')
# (182386, 'N')
# (182568, 'V')
# (182784, 'N')
# (182982, 'N')
# (183182, 'N')
# (183374, 'N')
# (183569, 'N')
# (183760, 'N')
# (183958, 'N')
# (184153, 'N')
# (184356, 'N')
# (184536, 'A')
# (184750, 'N')
# (184918, 'V')
# (185139, 'N')
# (185336, 'N')
# (185530, 'N')
# (185725, 'F')
# (185926, 'N')
# (186131, 'F')
# (186326, 'N')
# (186519, 'V')
# (186716, 'N')
# (186909, 'F')
# (187108, 'N')
# (187316, 'F')
# (187506, 'N')
# (187704, 'F')
# (187894, 'N')
# (188090, 'V')
# (188282, 'N')
# (188475, 'V')
# (188676, 'N')
# (188874, 'F')
# (189072, 'N')
# (189265, 'F')
# (189460, 'N')
# (189660, 'F')
# (189852, 'N')
# (190050, 'F')
# (190258, 'N')
# (190456, 'F')
# (190663, 'N')
# (190852, 'F')
# (191047, 'N')
# (191244, 'F')
# (191442, 'N')
# (191636, 'F')
# (191828, 'N')
# (192029, 'V')
# (192228, 'N')
# (192422, 'F')
# (192612, 'N')
# (192807, 'V')
# (193010, 'N')
# (193212, 'F')
# (193403, 'N')
# (193600, 'F')
# (193794, 'N')
# (193991, 'F')
# (194184, 'N')
# (194384, 'F')
# (194578, 'N')
# (194777, 'V')
# (194983, 'N')
# (195180, 'F')
# (195377, 'N')
# (195573, 'F')
# (195772, 'N')
# (195972, 'N')
# (196171, 'N')
# (196367, 'N')
# (196566, 'N')
# (196761, 'N')
# (196955, 'N')
# (197148, 'F')
# (197350, 'N')
# (197542, 'F')
# (197740, 'N')
# (197911, 'V')
# (198143, 'N')
# (198341, 'F')
# (198534, 'N')
# (198732, 'N')
# (198930, 'N')
# (199134, 'N')
# (199302, 'A')
# (199532, 'N')
# (199724, 'N')
# (199920, 'N')
# (200118, 'N')
# (200313, 'F')
# (200504, 'N')
# (200689, 'V')
# (200908, 'N')
# (201102, 'N')
# (201294, 'N')
# (201492, 'N')
# (201688, 'N')
# (201883, 'N')
# (202085, 'N')
# (202282, 'N')
# (202483, 'N')
# (202675, 'N')
# (202869, 'N')
# (203070, 'N')
# (203272, 'N')
# (203466, 'N')
# (203665, 'N')
# (203836, 'V')
# (204064, 'N')
# (204238, 'V')
# (204457, 'N')
# (204658, 'N')
# (204857, 'N')
# (205058, 'N')
# (205251, 'N')
# (205455, 'N')
# (205644, 'N')
# (205838, 'N')
# (206003, 'V')
# (206233, 'N')
# (206426, 'N')
# (206625, 'N')
# (206829, 'V')
# (207028, 'N')
# (207223, 'F')
# (207416, 'N')
# (207616, 'F')
# (207814, 'N')
# (208016, 'F')
# (208214, 'N')
# (208418, 'F')
# (208605, 'N')
# (208801, 'F')
# (208997, 'N')
# (209195, 'F')
# (209389, 'N')
# (209586, 'F')
# (209789, 'N')
# (209984, 'F')
# (210178, 'N')
# (210371, 'F')
# (210568, 'N')
# (210767, 'N')
# (210969, 'N')
# (211168, 'F')
# (211371, 'N')
# (211562, 'F')
# (211758, 'N')
# (211954, 'F')
# (212153, 'N')
# (212354, 'F')
# (212526, 'N')
# (212753, 'F')
# (212950, 'N')
# (213151, 'N')
# (213340, 'N')
# (213534, 'F')
# (213736, 'N')
# (213941, 'F')
# (214132, 'N')
# (214328, 'F')
# (214520, 'N')
# (214722, 'F')
# (214917, 'N')
# (215110, 'F')
# (215310, 'N')
# (215515, 'F')
# (215718, 'N')
# (215911, 'F')
# (216110, 'N')
# (216309, 'F')
# (216506, 'N')
# (216704, 'F')
# (216904, 'N')
# (217104, 'F')
# (217307, 'N')
# (217501, 'N')
# (217690, 'N')
# (217887, 'N')
# (218082, 'N')
# (218286, 'N')
# (218484, 'N')
# (218686, 'N')
# (218879, 'F')
# (219084, 'N')
# (219273, 'N')
# (219372, '+')
# (219471, 'V')
# (219677, 'N')
# (219878, 'V')
# (220071, 'N')
# (220256, 'V')
# (220363, '+')
# (220471, 'N')
# (220665, 'F')
# (220869, 'N')
# (221057, 'N')
# (221259, 'N')
# (221461, 'N')
# (221658, 'N')
# (221850, 'N')
# (222049, 'N')
# (222239, 'N')
# (222436, 'N')
# (222638, 'V')
# (222839, 'N')
# (223033, 'N')
# (223231, 'N')
# (223429, 'N')
# (223620, 'N')
# (223818, 'N')
# (224011, 'N')
# (224219, 'N')
# (224414, 'N')
# (224615, 'F')
# (224810, 'N')
# (224902, '+')
# (224994, 'V')
# (225208, 'N')
# (225384, 'V')
# (225608, 'N')
# (225777, 'V')
# (225896, '+')
# (226015, 'N')
# (226208, 'N')
# (226400, 'N')
# (226594, 'N')
# (226800, 'N')
# (226987, 'N')
# (227186, 'N')
# (227385, 'N')
# (227592, 'N')
# (227782, 'F')
# (227976, 'N')
# (228154, 'V')
# (228374, 'N')
# (228581, 'V')
# (228780, 'N')
# (228981, 'F')
# (229136, 'A')
# (229372, 'N')
# (229566, 'N')
# (229769, 'N')
# (229965, 'N')
# (230165, 'N')
# (230365, 'N')
# (230568, 'N')
# (230761, 'N')
# (230956, 'V')
# (231152, 'N')
# (231337, 'F')
# (231558, 'N')
# (231757, 'N')
# (231908, 'A')
# (232143, 'N')
# (232343, 'N')
# (232536, 'N')
# (232742, 'N')
# (232938, 'N')
# (233136, 'N')
# (233339, 'N')
# (233542, 'N')
# (233709, 'A')
# (233930, 'N')
# (234130, 'N')
# (234331, 'N')
# (234534, 'N')
# (234732, 'N')
# (234933, 'N')
# (235123, 'N')
# (235321, 'N')
# (235515, 'N')
# (235718, 'N')
# (235912, 'N')
# (236110, 'N')
# (236315, 'N')
# (236515, 'N')
# (236712, 'N')
# (236906, 'N')
# (237108, 'N')
# (237309, 'N')
# (237510, 'N')
# (237708, 'N')
# (237908, 'N')
# (238103, 'N')
# (238307, 'N')
# (238505, 'N')
# (238703, 'N')
# (238899, 'N')
# (239107, 'N')
# (239309, 'N')
# (239505, 'N')
# (239702, 'N')
# (239899, 'N')
# (240095, 'N')
# (240294, 'N')
# (240499, 'N')
# (240698, 'N')
# (240895, 'N')
# (241086, 'N')
# (241283, 'N')
# (241486, 'N')
# (241683, 'N')
# (241881, 'N')
# (242082, 'N')
# (242289, 'N')
# (242485, 'N')
# (242682, 'N')
# (242876, 'N')
# (243079, 'N')
# (243280, 'N')
# (243482, 'N')
# (243678, 'N')
# (243881, 'N')
# (244071, 'N')
# (244266, 'N')
# (244469, 'N')
# (244664, 'N')
# (244864, 'N')
# (245064, 'N')
# (245270, 'N')
# (245463, 'N')
# (245660, 'N')
# (245857, 'N')
# (246055, 'N')
# (246256, 'N')
# (246462, 'N')
# (246662, 'N')
# (246860, 'N')
# (247052, 'N')
# (247252, 'N')
# (247452, 'N')
# (247645, 'N')
# (247850, 'N')
# (248047, 'N')
# (248249, 'N')
# (248442, 'N')
# (248643, 'N')
# (248834, 'N')
# (249031, 'N')
# (249239, 'N')
# (249440, 'N')
# (249637, 'N')
# (249837, 'N')
# (250033, 'N')
# (250226, 'N')
# (250426, 'N')
# (250622, 'N')
# (250832, 'N')
# (251030, 'N')
# (251229, 'N')
# (251427, 'N')
# (251630, 'N')
# (251822, 'N')
# (252020, 'N')
# (252228, 'N')
# (252430, 'N')
# (252626, 'N')
# (252818, 'N')
# (253017, 'N')
# (253210, 'N')
# (253410, 'N')
# (253606, 'N')
# (253805, 'N')
# (254003, 'N')
# (254203, 'N')
# (254401, 'N')
# (254595, 'N')
# (254791, 'N')
# (254998, 'N')
# (255203, 'N')
# (255401, 'N')
# (255602, 'N')
# (255797, 'N')
# (255994, 'N')
# (256188, 'N')
# (256389, 'N')
# (256584, 'N')
# (256784, 'N')
# (256990, 'N')
# (257183, 'N')
# (257380, 'N')
# (257577, 'N')
# (257774, 'N')
# (257971, 'N')
# (258175, 'N')
# (258378, 'N')
# (258576, 'N')
# (258768, 'N')
# (258970, 'N')
# (259166, 'N')
# (259365, 'N')
# (259567, 'N')
# (259766, 'N')
# (259975, 'N')
# (260174, 'N')
# (260373, 'N')
# (260569, 'N')
# (260765, 'N')
# (260966, 'N')
# (261174, 'N')
# (261366, 'N')
# (261564, 'N')
# (261760, 'N')
# (261953, 'N')
# (262153, 'N')
# (262349, 'N')
# (262539, 'N')
# (262749, 'N')
# (262958, 'N')
# (263156, 'N')
# (263353, 'N')
# (263552, 'N')
# (263751, 'N')
# (263953, 'N')
# (264160, 'N')
# (264356, 'N')
# (264555, 'N')
# (264750, 'N')
# (264945, 'N')
# (265148, 'N')
# (265343, 'N')
# (265549, 'N')
# (265743, 'N')
# (265947, 'N')
# (266141, 'N')
# (266337, 'N')
# (266531, 'N')
# (266729, 'N')
# (266940, 'N')
# (267140, 'N')
# (267337, 'N')
# (267537, 'N')
# (267741, 'N')
# (267939, 'N')
# (268140, 'N')
# (268338, 'N')
# (268537, 'N')
# (268739, 'N')
# (268943, 'N')
# (269138, 'N')
# (269333, 'N')
# (269529, 'N')
# (269730, 'N')
# (269932, 'N')
# (270132, 'N')
# (270335, 'N')
# (270527, 'N')
# (270725, 'N')
# (270922, 'N')
# (271119, 'N')
# (271315, 'N')
# (271520, 'N')
# (271725, 'N')
# (271921, 'N')
# (272121, 'N')
# (272319, 'N')
# (272513, 'N')
# (272718, 'N')
# (272925, 'N')
# (273123, 'N')
# (273325, 'N')
# (273519, 'N')
# (273717, 'N')
# (273911, 'N')
# (274112, 'N')
# (274310, 'N')
# (274506, 'N')
# (274710, 'N')
# (274909, 'F')
# (275108, 'N')
# (275301, 'F')
# (275498, 'N')
# (275705, 'V')
# (275910, 'N')
# (276105, 'V')
# (276311, 'N')
# (276505, 'F')
# (276704, 'N')
# (276909, 'F')
# (277102, 'N')
# (277304, 'F')
# (277509, 'N')
# (277712, 'F')
# (277905, 'N')
# (278006, '+')
# (278108, 'V')
# (278300, 'N')
# (278497, 'V')
# (278700, 'N')
# (278903, 'V')
# (279099, 'N')
# (279271, 'V')
# (279384, '+')
# (279498, 'N')
# (279692, 'F')
# (279893, 'N')
# (280092, 'F')
# (280294, 'N')
# (280492, 'F')
# (280698, 'N')
# (280903, 'F')
# (281100, 'N')
# (281292, 'F')
# (281491, 'N')
# (281700, 'F')
# (281903, 'N')
# (282095, 'F')
# (282294, 'N')
# (282376, '+')
# (282458, 'V')
# (282688, 'N')
# (282886, 'V')
# (283078, 'N')
# (283285, 'V')
# (283383, '+')
# (283482, 'N')
# (283683, 'F')
# (283875, 'N')
# (284078, 'N')
# (284271, 'N')
# (284469, 'N')
# (284673, 'N')
# (284877, 'N')
# (285079, 'N')
# (285276, 'F')
# (285469, 'N')
# (285569, '+')
# (285669, 'V')
# (285875, 'N')
# (286069, 'V')
# (286269, 'N')
# (286436, 'V')
# (286675, 'N')
# (286868, 'V')
# (287065, 'N')
# (287261, 'V')
# (287361, '+')
# (287462, 'N')
# (287664, 'N')
# (287859, 'N')
# (288061, 'N')
# (288256, 'N')
# (288451, 'N')
# (288645, 'N')
# (288847, 'N')
# (289037, 'N')
# (289237, 'F')
# (289442, 'N')
# (289627, 'V')
# (289843, 'N')
# (290039, 'N')
# (290237, 'N')
# (290434, 'N')
# (290636, 'N')
# (290835, 'N')
# (291041, 'N')
# (291232, 'F')
# (291425, 'N')
# (291587, 'V')
# (291817, 'N')
# (292012, 'N')
# (292211, 'N')
# (292418, 'V')
# (292611, 'N')
# (292807, 'V')
# (293005, 'N')
# (293202, 'F')
# (293399, 'N')
# (293604, 'F')
# (293806, 'N')
# (294008, 'F')
# (294196, 'N')
# (294394, 'F')
# (294592, 'N')
# (294788, 'F')
# (294982, 'N')
# (295181, 'V')
# (295385, 'N')
# (295565, 'V')
# (295788, 'N')
# (295978, 'F')
# (296176, 'N')
# (296385, 'F')
# (296584, 'N')
# (296778, 'N')
# (296976, 'N')
# (297173, 'N')
# (297375, 'N')
# (297570, 'F')
# (297766, 'N')
# (297969, 'V')
# (298176, 'N')
# (298379, 'V')
# (298575, 'N')
# (298774, 'F')
# (298971, 'N')
# (299176, 'F')
# (299375, 'N')
# (299579, 'F')
# (299775, 'N')
# (299980, 'F')
# (300170, 'N')
# (300361, 'F')
# (300568, 'N')
# (300766, 'V')
# (300965, 'N')
# (301165, 'F')
# (301374, 'N')
# (301577, 'F')
# (301769, 'N')
# (301962, 'N')
# (302168, 'N')
# (302379, 'N')
# (302579, 'N')
# (302775, 'N')
# (302973, 'N')
# (303174, 'N')
# (303368, 'N')
# (303568, 'F')
# (303766, 'N')
# (303973, 'N')
# (304173, 'N')
# (304368, 'F')
# (304570, 'N')
# (304770, 'N')
# (304966, 'N')
# (305166, 'N')
# (305376, 'N')
# (305527, 'A')
# (305769, 'N')
# (305961, 'V')
# (306166, 'N')
# (306369, 'N')
# (306565, 'N')
# (306767, 'N')
# (306968, 'N')
# (307178, 'N')
# (307374, 'N')
# (307572, 'N')
# (307770, 'N')
# (307971, 'F')
# (308171, 'N')
# (308273, '+')
# (308376, 'V')
# (308577, 'N')
# (308761, 'V')
# (308970, 'N')
# (309166, 'V')
# (309270, '+')
# (309374, 'N')
# (309568, 'N')
# (309774, 'N')
# (309970, 'N')
# (310177, 'N')
# (310376, 'N')
# (310573, 'N')
# (310766, 'N')
# (310967, 'N')
# (311179, 'F')
# (311385, 'N')
# (311583, 'V')
# (311784, 'N')
# (311985, 'V')
# (312178, 'N')
# (312379, 'N')
# (312578, 'N')
# (312780, 'N')
# (312978, 'N')
# (313179, 'N')
# (313376, 'N')
# (313572, 'N')
# (313763, 'N')
# (313967, 'N')
# (314175, 'N')
# (314376, 'F')
# (314574, 'N')
# (314764, 'N')
# (314963, 'N')
# (315140, 'V')
# (315363, 'N')
# (315566, 'N')
# (315772, 'N')
# (315973, 'N')
# (316172, 'N')
# (316376, 'V')
# (316574, 'N')
# (316768, 'N')
# (316970, 'N')
# (317175, 'N')
# (317371, 'N')
# (317571, 'N')
# (317764, 'N')
# (317966, 'N')
# (318169, 'N')
# (318310, 'A')
# (318438, 'V')
# (318751, 'N')
# (318965, 'N')
# (319159, 'N')
# (319359, 'N')
# (319554, 'F')
# (319756, 'N')
# (319953, 'F')
# (320163, 'N')
# (320358, 'N')
# (320556, 'N')
# (320748, 'N')
# (320950, 'N')
# (321146, 'N')
# (321340, 'N')
# (321542, 'N')
# (321735, 'N')
# (321935, 'F')
# (322132, 'N')
# (322260, '+')
# (322328, 'V')
# (322505, 'V')
# (322720, 'F')
# (322850, '+')
# (322928, 'N')
# (323132, 'N')
# (323326, 'N')
# (323526, 'N')
# (323724, 'N')
# (323921, 'N')
# (324120, 'N')
# (324319, 'F')
# (324519, 'N')
# (324700, 'V')
# (324921, 'N')
# (325122, 'N')
# (325318, 'N')
# (325512, 'N')
# (325714, 'N')
# (325914, 'N')
# (326115, 'N')
# (326309, 'N')
# (326516, 'N')
# (326707, 'N')
# (326896, 'F')
# (327105, 'V')
# (327303, 'N')
# (327506, 'F')
# (327703, 'N')
# (327915, 'N')
# (328109, 'N')
# (328309, 'N')
# (328509, 'N')
# (328707, 'N')
# (328912, 'N')
# (329120, 'N')
# (329319, 'N')
# (329516, 'V')
# (329715, 'N')
# (329917, 'F')
# (330118, 'N')
# (330313, 'F')
# (330518, 'N')
# (330717, 'N')
# (330923, 'N')
# (331118, 'N')
# (331316, 'N')
# (331514, 'N')
# (331718, 'N')
# (331880, 'A')
# (332120, 'N')
# (332308, 'V')
# (332524, 'N')
# (332726, 'N')
# (332867, 'A')
# (333110, 'N')
# (333316, 'N')
# (333523, 'N')
# (333725, 'N')
# (333923, 'N')
# (334129, 'N')
# (334321, 'N')
# (334517, 'N')
# (334723, 'N')
# (334926, 'N')
# (335127, 'N')
# (335331, 'N')
# (335519, 'N')
# (335719, 'N')
# (335924, 'N')
# (336122, 'N')
# (336321, 'N')
# (336521, 'N')
# (336735, 'N')
# (336931, 'N')
# (337131, 'N')
# (337327, 'N')
# (337532, 'N')
# (337736, 'N')
# (337941, 'N')
# (338138, 'N')
# (338335, 'N')
# (338534, 'N')
# (338733, 'N')
# (338937, 'N')
# (339127, 'N')
# (339331, 'N')
# (339538, 'N')
# (339736, 'N')
# (339895, 'A')
# (340133, 'N')
# (340333, 'N')
# (340532, 'N')
# (340739, 'N')
# (340945, 'N')
# (341146, 'N')
# (341343, 'N')
# (341548, 'N')
# (341743, 'N')
# (341946, 'N')
# (342147, 'N')
# (342346, 'N')
# (342551, 'N')
# (342755, 'N')
# (342952, 'N')
# (343145, 'N')
# (343345, 'N')
# (343547, 'N')
# (343753, 'N')
# (343951, 'N')
# (344153, 'N')
# (344343, 'N')
# (344539, 'N')
# (344744, 'N')
# (344938, 'N')
# (345138, 'N')
# (345343, 'N')
# (345551, 'N')
# (345747, 'N')
# (345949, 'N')
# (346146, 'N')
# (346344, 'N')
# (346548, 'N')
# (346755, 'N')
# (346954, 'N')
# (347154, 'N')
# (347348, 'N')
# (347546, 'N')
# (347746, 'N')
# (347940, 'N')
# (348145, 'N')
# (348349, 'N')
# (348548, 'N')
# (348741, 'N')
# (348938, 'N')
# (349132, 'N')
# (349327, 'N')
# (349536, 'N')
# (349745, 'N')
# (349944, 'N')
# (350140, 'N')
# (350337, 'N')
# (350535, 'N')
# (350737, 'N')
# (350938, 'N')
# (351141, 'N')
# (351341, 'N')
# (351541, 'N')
# (351737, 'N')
# (351932, 'N')
# (352123, 'N')
# (352318, 'N')
# (352525, 'N')
# (352722, 'N')
# (352920, 'N')
# (353112, 'N')
# (353313, 'N')
# (353505, 'N')
# (353702, 'N')
# (353898, 'N')
# (354102, 'N')
# (354305, 'N')
# (354501, 'N')
# (354703, 'N')
# (354899, 'N')
# (355092, 'N')
# (355293, 'N')
# (355498, 'N')
# (355695, 'N')
# (355894, 'N')
# (356086, 'N')
# (356281, 'N')
# (356474, 'N')
# (356673, 'N')
# (356869, 'N')
# (357070, 'N')
# (357275, 'N')
# (357473, 'N')
# (357674, 'N')
# (357864, 'N')
# (358059, 'N')
# (358264, 'N')
# (358474, 'N')
# (358668, 'N')
# (358871, 'N')
# (359063, 'N')
# (359259, 'N')
# (359451, 'N')
# (359644, 'N')
# (359843, 'N')
# (360042, 'N')
# (360243, 'N')
# (360395, 'A')
# (360629, 'N')
# (360820, 'N')
# (361012, 'N')
# (361208, 'N')
# (361414, 'N')
# (361613, 'N')
# (361810, 'N')
# (362000, 'N')
# (362192, 'N')
# (362388, 'N')
# (362589, 'N')
# (362783, 'N')
# (362981, 'N')
# (363186, 'N')
# (363389, 'N')
# (363586, 'N')
# (363780, 'N')
# (363980, 'N')
# (364184, 'N')
# (364390, 'N')
# (364587, 'N')
# (364790, 'N')
# (364985, 'N')
# (365181, 'N')
# (365379, 'N')
# (365581, 'N')
# (365780, 'N')
# (365983, 'N')
# (366189, 'N')
# (366392, 'N')
# (366591, 'N')
# (366787, 'N')
# (366992, 'N')
# (367203, 'N')
# (367408, 'N')
# (367606, 'N')
# (367813, 'N')
# (368010, 'N')
# (368207, 'N')
# (368410, 'N')
# (368615, 'N')
# (368820, 'N')
# (369017, 'N')
# (369224, 'N')
# (369424, 'N')
# (369622, 'N')
# (369817, 'N')
# (370020, 'N')
# (370232, 'N')
# (370433, 'N')
# (370633, 'N')
# (370835, 'N')
# (371034, 'N')
# (371234, 'N')
# (371439, 'N')
# (371642, 'N')
# (371844, 'N')
# (372051, 'N')
# (372258, 'N')
# (372458, 'N')
# (372653, 'N')
# (372854, 'N')
# (373065, 'N')
# (373271, 'N')
# (373468, 'N')
# (373678, 'N')
# (373871, 'N')
# (374069, 'N')
# (374272, 'N')
# (374474, 'N')
# (374676, 'N')
# (374878, 'N')
# (375088, 'F')
# (375285, 'N')
# (375486, 'F')
# (375684, 'N')
# (375893, 'F')
# (376101, 'N')
# (376196, '+')
# (376292, 'V')
# (376507, 'N')
# (376690, 'V')
# (376909, 'N')
# (377087, 'V')
# (377312, 'N')
# (377477, 'V')
# (377597, '+')
# (377717, 'N')
# (377920, 'F')
# (378116, 'N')
# (378316, 'F')
# (378515, 'N')
# (378707, 'F')
# (378912, 'N')
# (379120, 'F')
# (379215, '+')
# (379318, 'V')
# (379489, 'V')
# (379676, 'V')
# (379901, 'V')
# (380044, '+')
# (380127, 'N')
# (380307, 'F')
# (380526, 'N')
# (380734, 'N')
# (380934, 'N')
# (381127, 'F')
# (381330, 'N')
# (381413, '+')
# (381497, 'V')
# (381732, 'N')
# (381930, 'V')
# (382133, 'N')
# (382313, 'V')
# (382399, '+')
# (382485, 'N')
# (382717, 'F')
# (382913, 'N')
# (383123, 'F')
# (383314, 'N')
# (383516, 'F')
# (383719, 'N')
# (383923, 'V')
# (384129, 'N')
# (384328, 'F')
# (384522, 'N')
# (384697, 'V')
# (384933, 'N')
# (385136, 'F')
# (385339, 'N')
# (385536, 'F')
# (385731, 'N')
# (385831, '+')
# (385932, 'V')
# (386134, 'N')
# (386325, 'V')
# (386527, 'N')
# (386736, 'V')
# (386932, 'N')
# (387129, 'V')
# (387327, 'N')
# (387528, 'V')
# (387729, 'N')
# (387935, 'V')
# (388036, '+')
# (388137, 'N')
# (388335, 'F')
# (388531, 'N')
# (388734, 'V')
# (388876, 'A')
# (389008, 'V')
# (389326, 'N')
# (389536, 'N')
# (389740, 'F')
# (389941, 'N')
# (390139, 'V')
# (390337, 'N')
# (390538, 'N')
# (390735, 'N')
# (390940, 'N')
# (391142, 'N')
# (391345, 'N')
# (391533, 'N')
# (391733, 'N')
# (391939, 'N')
# (392137, 'N')
# (392337, 'N')
# (392540, 'F')
# (392748, 'N')
# (392927, 'V')
# (393142, 'N')
# (393347, 'N')
# (393546, 'N')
# (393751, 'N')
# (393958, 'N')
# (394160, 'N')
# (394355, 'N')
# (394555, 'N')
# (394755, 'N')
# (394953, 'N')
# (395149, 'N')
# (395357, 'F')
# (395556, 'N')
# (395757, 'N')
# (395959, 'N')
# (396158, 'V')
# (396354, 'N')
# (396539, 'V')
# (396770, 'N')
# (396970, 'F')
# (397175, 'N')
# (397372, 'F')
# (397573, 'N')
# (397769, 'F')
# (397973, 'N')
# (398175, 'N')
# (398372, 'N')
# (398579, 'N')
# (398778, 'N')
# (398977, 'N')
# (399170, 'N')
# (399370, 'F')
# (399577, 'N')
# (399777, 'F')
# (399973, 'N')
# (400178, 'N')
# (400376, 'N')
# (400573, 'N')
# (400773, 'N')
# (400972, 'N')
# (401174, 'N')
# (401375, 'N')
# (401586, 'N')
# (401785, 'N')
# (401986, 'N')
# (402184, 'F')
# (402388, 'N')
# (402572, 'V')
# (402795, 'N')
# (402968, 'V')
# (403196, 'N')
# (403393, 'F')
# (403592, 'N')
# (403794, 'N')
# (403989, 'N')
# (404195, 'N')
# (404400, 'N')
# (404600, 'N')
# (404800, 'N')
# (405002, 'N')
# (405195, 'N')
# (405364, 'V')
# (405606, 'N')
# (405807, 'N')
# (406008, 'N')
# (406211, 'V')
# (406408, 'N')
# (406607, 'F')
# (406809, 'N')
# (407012, 'F')
# (407217, 'N')
# (407419, 'F')
# (407619, 'N')
# (407825, 'F')
# (408016, 'N')
# (408217, 'F')
# (408421, 'N')
# (408625, 'F')
# (408821, 'N')
# (409030, 'V')
# (409222, 'N')
# (409421, 'F')
# (409627, 'N')
# (409822, 'N')
# (410026, 'N')
# (410228, 'N')
# (410439, 'N')
# (410639, 'N')
# (410837, 'N')
# (411034, 'N')
# (411239, 'N')
# (411447, 'N')
# (411650, 'N')
# (411852, 'F')
# (412052, 'N')
# (412229, 'V')
# (412451, 'N')
# (412656, 'N')
# (412852, 'N')
# (413058, 'N')
# (413258, 'N')
# (413461, 'N')
# (413665, 'N')
# (413860, 'N')
# (414055, 'N')
# (414262, 'N')
# (414474, 'N')
# (414670, 'V')
# (414874, 'N')
# (415077, 'N')
# (415278, 'N')
# (415474, 'N')
# (415673, 'N')
# (415883, 'N')
# (416082, 'N')
# (416294, 'N')
# (416490, 'N')
# (416689, 'N')
# (416886, 'N')
# (417089, 'N')
# (417294, 'N')
# (417482, 'V')
# (417700, 'N')
# (417904, 'N')
# (418095, 'N')
# (418295, 'F')
# (418501, 'N')
# (418651, 'V')
# (418898, 'N')
# (419107, 'F')
# (419309, 'N')
# (419507, 'F')
# (419707, 'N')
# (419905, 'F')
# (420106, 'N')
# (420313, 'F')
# (420517, 'N')
# (420719, 'N')
# (420910, 'N')
# (421111, 'N')
# (421310, 'N')
# (421507, 'F')
# (421705, 'N')
# (421910, 'F')
# (422115, 'N')
# (422312, 'F')
# (422516, 'N')
# (422711, 'N')
# (422906, 'N')
# (423112, 'N')
# (423322, 'N')
# (423520, 'N')
# (423724, 'N')
# (423924, 'F')
# (424119, 'N')
# (424305, 'V')
# (424524, 'N')
# (424727, 'F')
# (424929, 'N')
# (425137, 'F')
# (425329, 'N')
# (425533, 'F')
# (425715, 'N')
# (425927, 'F')
# (426133, 'N')
# (426327, 'V')
# (426543, 'N')
# (426738, 'N')
# (426934, 'N')
# (427133, 'N')
# (427343, 'N')
# (427536, 'N')
# (427739, 'N')
# (427949, 'N')
# (428154, 'N')
# (428353, 'F')
# (428549, 'N')
# (428716, 'V')
# (428958, 'N')
# (429164, 'N')
# (429367, 'N')
# (429571, 'N')
# (429762, 'N')
# (429961, 'N')
# (430163, 'N')
# (430364, 'N')
# (430565, 'N')
# (430768, 'N')
# (430977, 'N')
# (431172, 'F')
# (431374, 'N')
# (431572, 'N')
# (431781, 'N')
# (431985, 'N')
# (432193, 'N')
# (432397, 'N')
# (432605, 'N')
# (432799, 'N')
# (432994, 'N')
# (433204, 'N')
# (433399, 'N')
# (433602, 'N')
# (433805, 'N')
# (434015, 'N')
# (434210, 'N')
# (434408, 'N')
# (434607, 'N')
# (434813, 'N')
# (435019, 'N')
# (435223, 'N')
# (435430, 'N')
# (435625, 'N')
# (435824, 'N')
# (436026, 'N')
# (436227, 'N')
# (436427, 'N')
# (436633, 'N')
# (436847, 'N')
# (437043, 'N')
# (437240, 'N')
# (437443, 'N')
# (437648, 'N')
# (437851, 'N')
# (438059, 'N')
# (438261, 'N')
# (438463, 'N')
# (438654, 'N')
# (438856, 'N')
# (439061, 'N')
# (439256, 'N')
# (439463, 'N')
# (439666, 'N')
# (439869, 'N')
# (440067, 'N')
# (440269, 'N')
# (440473, 'N')
# (440675, 'N')
# (440884, 'N')
# (441090, 'N')
# (441301, 'N')
# (441494, 'N')
# (441697, 'N')
# (441902, 'N')
# (442106, 'N')
# (442302, 'N')
# (442506, 'N')
# (442718, 'N')
# (442914, 'N')
# (443112, 'N')
# (443313, 'N')
# (443518, 'N')
# (443721, 'N')
# (443927, 'N')
# (444131, 'N')
# (444338, 'N')
# (444533, 'N')
# (444734, 'N')
# (444941, 'N')
# (445144, 'N')
# (445349, 'N')
# (445555, 'N')
# (445765, 'N')
# (445961, 'N')
# (446167, 'N')
# (446367, 'N')
# (446573, 'N')
# (446774, 'N')
# (446979, 'N')
# (447185, 'N')
# (447387, 'N')
# (447580, 'N')
# (447777, 'N')
# (447989, 'N')
# (448188, 'N')
# (448390, 'N')
# (448596, 'N')
# (448805, 'N')
# (449007, 'N')
# (449203, 'N')
# (449405, 'N')
# (449617, 'N')
# (449831, 'N')
# (450029, 'N')
# (450231, 'N')
# (450431, 'N')
# (450636, 'N')
# (450836, 'N')
# (451033, 'N')
# (451240, 'N')
# (451450, 'N')
# (451651, 'N')
# (451848, 'N')
# (452055, 'N')
# (452259, 'N')
# (452461, 'N')
# (452663, 'N')
# (452871, 'N')
# (453079, 'N')
# (453279, 'N')
# (453479, 'N')
# (453689, 'N')
# (453892, 'N')
# (454089, 'N')
# (454297, 'N')
# (454510, 'N')
# (454717, 'N')
# (454916, 'N')
# (455112, 'N')
# (455318, 'N')
# (455527, 'N')
# (455735, 'N')
# (455932, 'N')
# (456137, 'N')
# (456341, 'N')
# (456543, 'N')
# (456744, 'N')
# (456944, 'N')
# (457156, 'N')
# (457359, 'N')
# (457565, 'N')
# (457761, 'N')
# (457972, 'N')
# (458175, 'N')
# (458377, 'N')
# (458591, 'N')
# (458797, 'N')
# (458997, 'N')
# (459195, 'N')
# (459394, 'N')
# (459602, 'N')
# (459807, 'N')
# (460005, 'N')
# (460206, 'N')
# (460418, 'N')
# (460622, 'N')
# (460824, 'N')
# (461021, 'N')
# (461228, 'N')
# (461437, 'N')
# (461643, 'N')
# (461843, 'N')
# (462055, 'N')
# (462257, 'N')
# (462457, 'N')
# (462661, 'N')
# (462867, 'N')
# (463073, 'N')
# (463276, 'N')
# (463487, 'N')
# (463690, 'N')
# (463890, 'N')
# (464087, 'N')
# (464299, 'N')
# (464510, 'N')
# (464705, 'N')
# (464912, 'N')
# (465115, 'N')
# (465318, 'N')
# (465516, 'N')
# (465719, 'N')
# (465929, 'N')
# (466131, 'N')
# (466338, 'N')
# (466538, 'N')
# (466751, 'N')
# (466951, 'N')
# (467150, 'N')
# (467354, 'N')
# (467570, 'N')
# (467777, 'N')
# (467976, 'N')
# (468179, 'N')
# (468374, 'N')
# (468581, 'N')
# (468783, 'N')
# (468983, 'N')
# (469189, 'N')
# (469394, 'N')
# (469602, 'N')
# (469797, 'N')
# (469995, 'N')
# (470204, 'N')
# (470422, 'N')
# (470622, 'N')
# (470822, 'N')
# (471022, 'N')
# (471234, 'N')
# (471439, 'N')
# (471634, 'N')
# (471841, 'N')
# (472054, 'N')
# (472260, 'N')
# (472458, 'N')
# (472664, 'N')
# (472865, 'N')
# (473066, 'N')
# (473268, 'N')
# (473476, 'N')
# (473685, 'N')
# (473883, 'N')
# (474074, 'N')
# (474286, 'N')
# (474491, 'N')
# (474692, 'N')
# (474898, 'N')
# (475112, 'N')
# (475314, 'N')
# (475514, 'N')
# (475709, 'N')
# (475919, 'N')
# (476129, 'N')
# (476339, 'N')
# (476538, 'N')
# (476749, 'N')
# (476950, 'N')
# (477147, 'N')
# (477349, 'N')
# (477548, 'F')
# (477761, 'N')
# (477969, 'F')
# (478169, 'N')
# (478372, 'F')
# (478576, 'N')
# (478775, 'F')
# (478977, 'N')
# (479190, 'F')
# (479398, 'N')
# (479602, 'F')
# (479799, 'N')
# (480004, 'F')
# (480209, 'N')
# (480408, 'F')
# (480614, 'N')
# (480811, 'V')
# (481034, 'N')
# (481230, 'N')
# (481437, 'N')
# (481637, 'F')
# (481829, 'N')
# (482035, 'F')
# (482247, 'N')
# (482454, 'V')
# (482652, 'N')
# (482847, 'F')
# (483046, 'N')
# (483239, 'V')
# (483459, 'N')
# (483662, 'F')
# (483866, 'N')
# (484081, 'V')
# (484283, 'N')
# (484482, 'F')
# (484679, 'N')
# (484888, 'F')
# (485099, 'N')
# (485295, 'F')
# (485498, 'N')
# (485698, 'F')
# (485904, 'N')
# (486096, 'F')
# (486295, 'N')
# (486464, 'V')
# (486709, 'N')
# (486914, 'F')
# (487113, 'N')
# (487323, 'V')
# (487517, 'N')
# (487715, 'F')
# (487919, 'N')
# (488135, 'F')
# (488338, 'N')
# (488538, 'F')
# (488735, 'N')
# (488940, 'F')
# (489140, 'N')
# (489337, 'F')
# (489547, 'N')
# (489755, 'V')
# (489946, 'N')
# (490150, 'F')
# (490360, 'N')
# (490555, 'N')
# (490757, 'N')
# (490963, 'N')
# (491172, 'N')
# (491371, 'N')
# (491568, 'N')
# (491774, 'F')
# (491977, 'N')
# (492177, 'V')
# (492376, 'N')
# (492590, 'N')
# (492800, 'N')
# (492997, 'N')
# (493201, 'N')
# (493403, 'F')
# (493601, 'N')
# (493804, 'N')
# (494016, 'N')
# (494221, 'N')
# (494420, 'N')
# (494614, 'N')
# (494813, 'N')
# (495022, 'N')
# (495217, 'N')
# (495420, 'F')
# (495624, 'N')
# (495795, 'V')
# (496031, 'N')
# (496232, 'N')
# (496429, 'N')
# (496534, '+')
# (496639, 'V')
# (496845, 'N')
# (497052, 'V')
# (497256, 'N')
# (497460, 'V')
# (497557, '+')
# (497655, 'N')
# (497856, 'F')
# (498062, 'N')
# (498263, 'N')
# (498466, 'N')
# (498675, 'N')
# (498879, 'N')
# (499073, 'N')
# (499268, 'N')
# (499475, 'N')
# (499677, 'N')
# (499781, '+')
# (499886, 'V')
# (500090, 'N')
# (500262, 'V')
# (500491, 'N')
# (500674, 'V')
# (500786, '+')
# (500898, 'N')
# (501104, 'F')
# (501311, 'N')
# (501512, 'N')
# (501716, 'N')
# (501921, 'N')
# (502124, 'N')
# (502320, 'N')
# (502521, 'N')
# (502737, 'N')
# (502943, 'N')
# (503142, 'N')
# (503334, 'N')
# (503539, 'F')
# (503743, 'N')
# (503940, 'V')
# (504147, 'F')
# (504328, 'V')
# (504560, 'N')
# (504761, 'N')
# (504960, 'F')
# (505165, 'F')
# (505367, 'N')
# (505573, 'F')
# (505780, 'N')
# (505987, 'F')
# (506189, 'N')
# (506383, 'F')
# (506587, 'N')
# (506795, 'V')
# (506988, 'N')
# (507196, 'F')
# (507402, 'N')
# (507612, 'N')
# (507805, 'N')
# (508006, 'N')
# (508205, 'N')
# (508415, 'N')
# (508623, 'N')
# (508822, 'F')
# (509027, 'N')
# (509213, 'V')
# (509429, 'N')
# (509629, 'N')
# (509835, 'N')
# (510046, 'N')
# (510242, 'N')
# (510447, 'N')
# (510650, 'N')
# (510860, 'F')
# (511052, 'N')
# (511251, 'F')
# (511461, 'N')
# (511673, 'V')
# (511868, 'N')
# (512069, 'F')
# (512264, 'N')
# (512471, 'N')
# (512679, 'N')
# (512870, 'F')
# (513074, 'N')
# (513283, 'N')
# (513491, 'N')
# (513688, 'F')
# (513894, 'F')
# (514057, 'V')
# (514302, 'N')
# (514506, 'F')
# (514710, 'N')
# (514922, 'F')
# (515112, 'N')
# (515314, 'N')
# (515518, 'N')
# (515721, 'N')
# (515922, 'N')
# (516125, 'N')
# (516335, 'N')
# (516531, 'F')
# (516734, 'N')
# (516934, 'N')
# (517133, 'N')
# (517337, 'F')
# (517549, 'N')
# (517754, 'F')
# (517950, 'N')
# (518148, 'V')
# (518291, 'A')
# (518543, 'N')
# (518744, 'N')
# (518957, 'N')
# (519169, 'N')
# (519369, 'N')
# (519567, 'N')
# (519770, 'N')
# (519971, 'N')
# (520173, 'F')
# (520382, 'N')
# (520567, 'V')
# (520791, 'N')
# (520986, 'N')
# (521188, 'N')
# (521394, 'N')
# (521592, 'N')
# (521793, 'N')
# (522002, 'N')
# (522208, 'N')
# (522404, 'N')
# (522610, 'N')
# (522817, 'N')
# (523018, 'N')
# (523222, 'N')
# (523436, 'V')
# (523636, 'N')
# (523839, 'N')
# (524039, 'N')
# (524247, 'F')
# (524449, 'N')
# (524646, 'F')
# (524854, 'N')
# (525002, 'A')
# (525252, 'N')
# (525457, 'V')
# (525663, 'N')
# (525866, 'F')
# (526065, 'N')
# (526278, 'F')
# (526486, 'N')
# (526687, 'N')
# (526883, 'N')
# (527092, 'N')
# (527299, 'N')
# (527494, 'N')
# (527698, 'N')
# (527907, 'N')
# (528121, 'N')
# (528318, 'N')
# (528524, 'N')
# (528729, 'N')
# (528926, 'N')
# (529130, 'F')
# (529339, 'N')
# (529547, 'N')
# (529749, 'N')
# (529942, 'N')
# (530139, 'N')
# (530344, 'N')
# (530553, 'N')
# (530763, 'N')
# (530963, 'N')
# (531169, 'N')
# (531375, 'N')
# (531584, 'N')
# (531781, 'N')
# (531984, 'F')
# (532199, 'N')
# (532409, 'N')
# (532613, 'N')
# (532806, 'F')
# (533014, 'N')
# (533222, 'N')
# (533418, 'N')
# (533619, 'N')
# (533827, 'N')
# (534041, 'N')
# (534233, 'N')
# (534436, 'N')
# (534638, 'N')
# (534847, 'N')
# (535051, 'N')
# (535255, 'F')
# (535460, 'N')
# (535643, 'V')
# (535873, 'N')
# (536010, 'a')
# (536146, 'V')
# (536469, 'N')
# (536684, 'N')
# (536887, 'N')
# (537090, 'N')
# (537299, 'N')
# (537494, 'N')
# (537688, 'N')
# (537895, 'N')
# (538108, 'N')
# (538307, 'N')
# (538508, 'N')
# (538706, 'N')
# (538909, 'N')
# (539110, 'N')
# (539309, 'N')
# (539517, 'N')
# (539725, 'N')
# (539932, 'N')
# (540133, 'N')
# (540341, 'N')
# (540538, 'N')
# (540746, 'N')
# (540961, 'N')
# (541163, 'N')
# (541366, 'N')
# (541572, 'N')
# (541772, 'N')
# (541969, 'N')
# (542176, 'N')
# (542376, 'N')
# (542580, 'N')
# (542787, 'N')
# (542989, 'N')
# (543195, 'N')
# (543389, 'N')
# (543592, 'N')
# (543801, 'N')
# (544009, 'N')
# (544217, 'N')
# (544421, 'N')
# (544621, 'N')
# (544827, 'N')
# (545034, 'N')
# (545230, 'N')
# (545438, 'N')
# (545650, 'N')
# (545854, 'N')
# (546056, 'N')
# (546259, 'N')
# (546460, 'N')
# (546662, 'N')
# (546873, 'N')
# (547080, 'N')
# (547282, 'N')
# (547478, 'N')
# (547684, 'N')
# (547893, 'N')
# (548088, 'N')
# (548295, 'N')
# (548508, 'N')
# (548720, 'N')
# (548918, 'N')
# (549124, 'N')
# (549331, 'N')
# (549535, 'N')
# (549742, 'N')
# (549952, 'N')
# (550162, 'N')
# (550361, 'N')
# (550557, 'N')
# (550754, 'N')
# (550965, 'N')
# (551171, 'N')
# (551371, 'N')
# (551577, 'N')
# (551783, 'N')
# (551992, 'N')
# (552188, 'N')
# (552386, 'N')
# (552592, 'N')
# (552811, 'N')
# (553018, 'N')
# (553219, 'N')
# (553414, 'N')
# (553617, 'N')
# (553833, 'N')
# (554036, 'N')
# (554240, 'N')
# (554444, 'N')
# (554654, 'N')
# (554862, 'N')
# (555061, 'N')
# (555257, 'N')
# (555467, 'N')
# (555681, 'N')
# (555879, 'N')
# (556083, 'N')
# (556283, 'N')
# (556492, 'N')
# (556690, 'N')
# (556895, 'N')
# (557103, 'N')
# (557307, 'N')
# (557521, 'N')
# (557727, 'N')
# (557928, 'N')
# (558124, 'N')
# (558331, 'N')
# (558548, 'N')
# (558753, 'N')
# (558957, 'N')
# (559158, 'N')
# (559363, 'N')
# (559564, 'N')
# (559765, 'N')
# (559965, 'N')
# (560174, 'N')
# (560387, 'N')
# (560585, 'N')
# (560786, 'N')
# (560986, 'N')
# (561196, 'N')
# (561408, 'N')
# (561616, 'N')
# (561823, 'N')
# (562031, 'N')
# (562227, 'N')
# (562427, 'N')
# (562631, 'N')
# (562838, 'N')
# (563047, 'N')
# (563186, 'a')
# (563322, 'a')
# (563558, 'N')
# (563799, 'N')
# (563996, 'N')
# (564201, 'N')
# (564414, 'N')
# (564624, 'N')
# (564827, 'N')
# (565024, 'N')
# (565221, 'N')
# (565423, 'N')
# (565635, 'N')
# (565837, 'N')
# (566039, 'N')
# (566244, 'N')
# (566454, 'N')
# (566654, 'N')
# (566857, 'N')
# (567055, 'N')
# (567267, 'N')
# (567483, 'N')
# (567683, 'N')
# (567883, 'N')
# (568084, 'N')
# (568287, 'N')
# (568489, 'N')
# (568689, 'N')
# (568898, 'N')
# (569100, 'N')
# (569308, 'N')
# (569512, 'N')
# (569720, 'N')
# (569916, 'N')
# (570118, 'N')
# (570332, 'N')
# (570545, 'N')
# (570746, 'N')
# (570946, 'N')
# (571148, 'N')
# (571356, 'N')
# (571558, 'N')
# (571760, 'N')
# (571973, 'N')
# (572164, 'F')
# (572376, 'N')
# (572580, 'N')
# (572787, 'N')
# (572988, 'N')
# (573189, 'N')
# (573398, 'N')
# (573603, 'N')
# (573814, 'N')
# (574012, 'N')
# (574211, 'N')
# (574416, 'N')
# (574623, 'N')
# (574837, 'N')
# (575037, 'N')
# (575245, 'N')
# (575442, 'N')
# (575648, 'N')
# (575854, 'N')
# (576060, 'N')
# (576267, 'N')
# (576467, 'N')
# (576678, 'N')
# (576883, 'N')
# (577082, 'N')
# (577280, 'F')
# (577485, 'N')
# (577591, '+')
# (577697, 'V')
# (577901, 'N')
# (578090, 'V')
# (578305, 'N')
# (578495, 'V')
# (578609, '+')
# (578723, 'N')
# (578923, 'N')
# (579130, 'N')
# (579345, 'F')
# (579555, 'N')
# (579751, 'F')
# (579948, 'N')
# (580154, 'F')
# (580366, 'N')
# (580562, 'F')
# (580766, 'N')
# (580973, 'V')
# (581182, 'N')
# (581388, 'F')
# (581581, 'N')
# (581781, 'F')
# (581998, 'N')
# (582212, 'F')
# (582408, 'N')
# (582615, 'V')
# (582816, 'N')
# (583016, 'V')
# (583225, 'N')
# (583424, 'F')
# (583629, 'N')
# (583838, 'V')
# (584049, 'N')
# (584244, 'V')
# (584444, 'N')
# (584612, 'V')
# (584764, 'V')
# (585070, 'N')
# (585271, 'N')
# (585473, 'N')
# (585679, 'N')
# (585883, 'N')
# (586079, 'N')
# (586280, 'V')
# (586495, 'N')
# (586699, 'N')
# (586903, 'N')
# (587087, 'V')
# (587315, 'N')
# (587513, 'N')
# (587715, 'N')
# (587929, 'N')
# (588139, 'N')
# (588338, 'N')
# (588535, 'N')
# (588734, 'N')
# (588940, 'V')
# (589149, 'N')
# (589342, 'N')
# (589544, 'N')
# (589735, 'V')
# (589963, 'N')
# (590170, 'N')
# (590363, 'N')
# (590564, 'N')
# (590777, 'N')
# (590987, 'N')
# (591157, 'V')
# (591388, 'N')
# (591592, 'N')
# (591789, 'N')
# (591990, 'N')
# (592193, 'N')
# (592404, 'N')
# (592570, 'V')
# (592811, 'N')
# (593016, 'N')
# (593213, 'N')
# (593411, 'N')
# (593619, 'N')
# (593826, 'N')
# (594026, 'N')
# (594230, 'N')
# (594432, 'F')
# (594627, 'N')
# (594828, 'N')
# (595039, 'N')
# (595235, 'N')
# (595436, 'N')
# (595646, 'V')
# (595853, 'N')
# (596053, 'N')
# (596251, 'N')
# (596457, 'V')
# (596667, 'N')
# (596875, 'F')
# (597073, 'N')
# (597276, 'F')
# (597481, 'N')
# (597686, 'F')
# (597886, 'N')
# (598082, 'F')
# (598295, 'N')
# (598501, 'N')
# (598702, 'N')
# (598853, 'A')
# (599094, 'N')
# (599302, 'F')
# (599501, 'N')
# (599717, 'N')
# (599923, 'N')
# (600125, 'N')
# (600325, 'N')
# (600533, 'N')
# (600734, 'N')
# (600936, 'N')
# (601139, 'N')
# (601350, 'N')
# (601561, 'N')
# (601760, 'N')
# (601965, 'N')
# (602170, 'N')
# (602365, 'N')
# (602571, 'V')
# (602782, 'N')
# (602988, 'N')
# (603189, 'N')
# (603363, 'V')
# (603580, 'N')
# (603789, 'F')
# (603994, 'N')
# (604202, 'N')
# (604401, 'N')
# (604606, 'N')
# (604809, 'N')
# (605020, 'N')
# (605222, 'N')
# (605426, 'N')
# (605639, 'N')
# (605847, 'N')
# (606051, 'N')
# (606232, 'V')
# (606458, 'N')
# (606639, 'V')
# (606859, 'N')
# (607072, 'N')
# (607273, 'N')
# (607479, 'N')
# (607679, 'N')
# (607890, 'N')
# (608085, 'N')
# (608291, 'N')
# (608501, 'N')
# (608704, 'F')
# (608909, 'N')
# (609098, 'V')
# (609323, 'N')
# (609521, 'N')
# (609730, 'N')
# (609910, 'V')
# (610138, 'N')
# (610344, 'N')
# (610550, 'N')
# (610759, 'N')
# (610952, 'N')
# (611151, 'N')
# (611362, 'N')
# (611574, 'N')
# (611769, 'N')
# (611972, 'N')
# (612172, 'N')
# (612381, 'F')
# (612580, 'N')
# (612759, 'V')
# (612987, 'N')
# (613202, 'N')
# (613410, 'N')
# (613606, 'V')
# (613790, 'N')
# (614021, 'N')
# (614224, 'N')
# (614433, 'N')
# (614643, 'N')
# (614844, 'N')
# (615047, 'N')
# (615251, 'N')
# (615447, 'N')
# (615652, 'F')
# (615854, 'N')
# (616062, 'F')
# (616262, 'N')
# (616449, 'V')
# (616672, 'N')
# (616873, 'V')
# (617073, 'N')
# (617283, 'F')
# (617497, 'N')
# (617696, 'N')
# (617902, 'N')
# (618105, 'N')
# (618303, 'N')
# (618508, 'N')
# (618710, 'N')
# (618921, 'N')
# (619122, 'N')
# (619329, 'F')
# (619534, 'N')
# (619735, 'F')
# (619931, 'N')
# (620121, 'V')
# (620353, 'N')
# (620555, 'N')
# (620759, 'N')
# (620960, 'N')
# (621166, 'N')
# (621368, 'N')
# (621565, 'N')
# (621772, 'N')
# (621984, 'N')
# (622192, 'N')
# (622390, 'N')
# (622593, 'F')
# (622799, 'N')
# (622969, 'V')
# (623212, 'N')
# (623419, 'F')
# (623625, 'N')
# (623832, 'N')
# (624029, 'N')
# (624225, 'N')
# (624433, 'N')
# (624636, 'N')
# (624839, 'N')
# (625043, 'N')
# (625249, 'N')
# (625449, 'N')
# (625650, 'N')
# (625852, 'N')
# (626059, 'N')
# (626275, 'N')
# (626475, 'N')
# (626680, 'F')
# (626885, 'N')
# (627089, 'F')
# (627291, 'N')
# (627490, 'V')
# (627706, 'N')
# (627914, 'N')
# (628119, 'N')
# (628324, 'N')
# (628524, 'N')
# (628724, 'N')
# (628933, 'N')
# (629140, 'N')
# (629348, 'N')
# (629557, 'N')
# (629750, 'N')
# (629957, 'N')
# (630161, 'N')
# (630316, 'A')
# (630563, 'N')
# (630775, 'N')
# (630982, 'N')
# (631182, 'N')
# (631393, 'N')
# (631594, 'N')
# (631795, 'N')
# (632007, 'N')
# (632216, 'N')
# (632419, 'N')
# (632622, 'N')
# (632828, 'V')
# (633025, 'N')
# (633226, 'V')
# (633440, 'N')
# (633646, 'N')
# (633852, 'N')
# (634057, 'N')
# (634264, 'N')
# (634458, 'N')
# (634662, 'N')
# (634871, 'N')
# (635079, 'N')
# (635283, 'N')
# (635496, 'N')
# (635699, 'V')
# (635894, 'N')
# (636081, 'V')
# (636305, 'N')
# (636519, 'N')
# (636722, 'N')
# (636925, 'N')
# (637131, 'N')
# (637331, 'N')
# (637527, 'N')
# (637731, 'N')
# (637945, 'N')
# (638149, 'N')
# (638353, 'N')
# (638539, 'N')
# (638759, 'N')
# (638965, 'N')
# (639162, 'N')
# (639370, 'V')
# (639583, 'N')
# (639795, 'F')
# (639994, 'N')
# (640200, 'F')
# (640401, 'N')
# (640604, 'N')
# (640812, 'N')
# (641026, 'N')
# (641232, 'N')
# (641428, 'N')
# (641632, 'N')
# (641834, 'N')
# (642035, 'N')
# (642234, 'N')
# (642445, 'N')
# (642657, 'N')
# (642855, 'N')
# (643055, 'F')
# (643257, 'N')
# (643430, 'V')
# (643670, 'N')
# (643881, 'F')
# (644087, 'N')
# (644295, 'N')
# (644490, 'N')
# (644688, 'N')
# (644901, 'N')
# (645105, 'N')
# (645311, 'N')
# (645512, 'N')
# (645722, 'N')
# (645924, 'N')
# (646120, 'N')
# (646318, 'N')
# (646529, 'N')
# (646741, 'N')
# (646939, 'N')
# (647147, 'N')
# (647347, 'N')
# (647546, 'F')
# (647748, 'N')
# (647953, 'N')
# (648163, 'N')
# (648366, 'N')
# (648519, 'A')
# (648762, 'N')
# (648974, 'N')
# (649174, 'N')
# (649374, 'N')
# (649577, 'N')
# (649790, 'N')
# (649992, 'N')
# Canal 0
# Canal 1
# [[-0.215  0.095]
#  [-0.215  0.095]
#  [-0.215  0.095]
#  ...,
#  [-1.19  -0.465]
#  [-1.135 -0.4  ]
#  [-1.28   0.   ]]
# (9, '+')
# (50, 'R')
# (312, 'V')
# (835, 'R')
# (1078, 'V')
# (1588, 'R')
# (1821, 'V')
# (2342, 'R')
# (2593, 'V')
# (3111, 'R')
# (3357, 'V')
# (3857, 'R')
# (4092, 'V')
# (4637, 'R')
# (4889, 'V')
# (5409, 'R')
# (5648, 'V')
# (6160, 'R')
# (6408, 'V')
# (6939, 'R')
# (7191, 'V')
# (7700, 'R')
# (7937, 'V')
# (8437, 'R')
# (8694, 'V')
# (9215, 'R')
# (9463, 'V')
# (9949, 'R')
# (10196, 'V')
# (10689, 'R')
# (10939, 'V')
# (11450, 'R')
# (11699, 'V')
# (12197, 'R')
# (12436, 'V')
# (12936, 'R')
# (13200, 'V')
# (13348, 'V')
# (13717, 'L')
# (13868, '+')
# (13967, 'V')
# (14125, 'V')
# (14263, 'V')
# (14414, '+')
# (14522, 'L')
# (14665, '[')
# (14689, '+')
# (14894, '!')
# (15018, '!')
# (15138, '!')
# (15258, '!')
# (15387, '!')
# (15519, '!')
# (15642, '!')
# (15759, '!')
# (15906, '!')
# (16015, '!')
# (16138, '!')
# (16262, '!')
# (16383, '!')
# (16496, '!')
# (16611, '!')
# (16710, '!')
# (16822, '!')
# (16936, '!')
# (17055, '!')
# (17218, '!')
# (17346, '!')
# (17509, '!')
# (17618, '!')
# (17730, '!')
# (17857, '!')
# (17976, '!')
# (18132, '!')
# (18256, '!')
# (18350, ']')
# (18396, '+')
# (18825, 'R')
# (19070, 'V')
# (19579, 'R')
# (19715, '[')
# (19760, '+')
# (19836, '!')
# (19964, '!')
# (20077, '!')
# (20183, '!')
# (20297, '!')
# (20402, '!')
# (20521, '!')
# (20640, '!')
# (20748, '!')
# (20851, '!')
# (20962, '!')
# (21092, '!')
# (21183, '!')
# (21315, '!')
# (21432, '!')
# (21608, '!')
# (21731, ']')
# (21827, '+')
# (22117, 'R')
# (22262, '+')
# (22383, 'V')
# (22513, 'V')
# (22665, 'V')
# (22774, '+')
# (22883, 'L')
# (23174, 'L')
# (23502, 'L')
# (23746, 'V')
# (24177, 'R')
# (24535, 'L')
# (24866, 'L')
# (25185, 'L')
# (25496, 'L')
# (25627, '+')
# (25758, 'V')
# (26164, 'L')
# (26399, 'V')
# (26810, 'R')
# (27055, 'V')
# (27256, '+')
# (27458, 'R')
# (27785, 'L')
# (28039, 'V')
# (28182, 'V')
# (28717, 'R')
# (28965, 'V')
# (29115, 'V')
# (29455, 'R')
# (29847, 'L')
# (30088, 'V')
# (30567, 'R')
# (30831, 'V')
# (31261, 'R')
# (31614, 'L')
# (31944, 'L')
# (32284, 'L')
# (32637, 'L')
# (32985, 'L')
# (33339, 'L')
# (33604, 'V')
# (33996, 'R')
# (34347, 'L')
# (34708, 'L')
# (35076, 'L')
# (35420, 'L')
# (35760, 'L')
# (36105, 'L')
# (36439, 'L')
# (36792, 'L')
# (37147, 'L')
# (37500, 'L')
# (37848, 'L')
# (38182, 'L')
# (38509, 'L')
# (38867, 'L')
# (39234, 'L')
# (39575, 'L')
# (39924, 'L')
# (40264, 'L')
# (40599, 'L')
# (40951, 'L')
# (41301, 'L')
# (41654, 'L')
# (42000, 'L')
# (42331, 'L')
# (42660, 'L')
# (42985, 'L')
# ...
# (406105, 'N')
# (406572, 'N')
# (406941, 'N')
# (407289, 'N')
# (407629, 'N')
# (408138, 'N')
# (408548, 'N')
# (408923, 'N')
# (409297, 'N')
# (409616, 'N')
# (409942, 'N')
# (410285, 'N')
# (410690, 'N')
# (411060, 'N')
# (411504, 'N')
# (411844, 'N')
# (412190, 'N')
# (412560, 'N')
# (412957, 'N')
# (413512, 'N')
# (413957, 'N')
# (414373, 'N')
# (414758, 'N')
# (415150, 'N')
# (415535, 'N')
# (415870, 'N')
# (416228, 'N')
# (416678, 'N')
# (416802, '~')
# (417024, 'N')
# (417409, 'N')
# (417846, 'N')
# (418198, 'N')
# (418579, 'N')
# (418964, 'N')
# (419358, 'N')
# (419761, 'N')
# (420144, 'N')
# (420515, 'N')
# (420845, 'N')
# (421252, 'N')
# (421669, 'N')
# (421766, '~')
# (422157, 'N')
# (422524, 'N')
# (422921, 'N')
# (423315, 'N')
# (423726, 'N')
# (424115, 'N')
# (424505, 'N')
# (424861, 'N')
# (425244, 'N')
# (425627, 'N')
# (426020, 'N')
# (426448, 'N')
# (427064, 'N')
# (427428, 'N')
# (427840, 'N')
# (428240, 'N')
# (428661, 'N')
# (429039, 'N')
# (429133, '~')
# (429396, 'N')
# (429720, '~')
# (429767, 'N')
# (430176, 'N')
# (430563, 'N')
# (430952, 'N')
# (431494, 'N')
# (431978, 'N')
# (432421, 'N')
# (432815, 'N')
# (433193, 'N')
# (433562, 'N')
# (433922, 'N')
# (434313, 'N')
# (434700, 'N')
# (435093, 'N')
# (435657, 'j')
# (436069, 'N')
# (436469, 'N')
# (436887, 'N')
# (437295, 'N')
# (437548, '~')
# (437665, 'N')
# (438029, 'N')
# (438399, 'N')
# (438760, 'N')
# (439133, 'N')
# (439548, 'N')
# (439987, 'N')
# (440424, 'N')
# (440857, 'N')
# (441261, 'N')
# (441645, 'N')
# (442028, 'N')
# (442396, 'N')
# (442751, 'N')
# (443135, 'N')
# (443510, 'N')
# (443873, 'N')
# (444227, 'N')
# (444599, 'N')
# (444956, 'N')
# (445358, 'N')
# (445747, 'N')
# (446121, 'N')
# (446477, 'N')
# (446837, 'N')
# (447193, 'N')
# (447588, 'N')
# (448058, 'N')
# (448401, 'N')
# (448753, 'N')
# (449123, 'N')
# (449488, 'N')
# (449861, 'N')
# (450223, 'N')
# (450567, 'N')
# (450908, 'N')
# (451250, 'N')
# (451613, 'N')
# (451970, 'N')
# (452321, 'N')
# (452444, '~')
# (452648, 'N')
# (452977, 'N')
# (453327, 'N')
# (453665, 'N')
# (454026, 'N')
# (454362, 'N')
# (454712, 'N')
# (455049, 'N')
# (455366, 'N')
# (455716, 'N')
# (456062, 'N')
# (456422, 'N')
# (456760, 'N')
# (457078, 'N')
# (457258, 'V')
# (457752, 'N')
# (458096, 'N')
# (458454, 'N')
# (458806, 'N')
# (459137, 'N')
# (459451, 'N')
# (459785, 'N')
# (460136, 'N')
# (460497, 'N')
# (460856, 'N')
# (461216, 'N')
# (461555, 'N')
# (461899, 'N')
# (462239, 'N')
# (462602, 'N')
# (462939, 'N')
# (463287, 'N')
# (463624, 'N')
# (463931, 'N')
# (464259, 'N')
# (464607, 'N')
# (464962, 'N')
# (465310, 'N')
# (465651, 'N')
# (465994, 'N')
# (466317, 'N')
# (466653, 'N')
# (467012, 'N')
# (467346, 'N')
# (467668, 'N')
# (467985, 'N')
# (468302, 'N')
# (468617, 'N')
# (468959, 'N')
# (469316, 'N')
# (469639, 'N')
# (469978, 'N')
# (470137, '~')
# (470321, 'N')
# (470643, 'N')
# (470982, 'N')
# (471316, 'N')
# (471655, 'N')
# (471985, 'N')
# (472305, 'N')
# (472602, 'N')
# (472919, 'N')
# (473247, 'N')
# (473577, 'N')
# (473890, 'N')
# (474218, 'N')
# (474534, 'N')
# (474844, 'N')
# (475171, 'N')
# (475510, 'N')
# (475848, 'N')
# (476163, 'N')
# (476494, 'N')
# (476813, 'N')
# (477112, 'N')
# (477446, 'N')
# (477790, 'N')
# (478143, 'N')
# (478464, 'N')
# (478794, 'N')
# (479123, 'N')
# (479446, 'N')
# (479794, 'N')
# (480157, 'N')
# (480504, 'N')
# (480835, 'N')
# (481163, 'N')
# (481505, 'N')
# (481837, 'N')
# (482191, 'N')
# (482547, 'N')
# (482885, 'N')
# (483198, 'N')
# (483523, 'N')
# (483851, 'N')
# (484196, 'N')
# (484536, 'N')
# (484857, 'N')
# (485193, 'N')
# (485517, 'N')
# (485840, 'N')
# (486183, 'N')
# (486531, 'N')
# (486869, 'N')
# (487193, 'N')
# (487526, 'N')
# (487849, 'N')
# (488180, 'N')
# (488539, 'N')
# (488880, 'N')
# (489211, 'N')
# (489576, 'N')
# (489912, 'N')
# (490263, 'N')
# (490593, 'N')
# (490797, 'V')
# (490898, 'x')
# (491338, 'N')
# (491647, 'N')
# (491967, 'N')
# (492302, 'N')
# (492626, 'N')
# (492946, 'N')
# (493292, 'N')
# (493611, 'N')
# (493901, 'N')
# (494200, 'N')
# (494523, 'N')
# (494853, 'N')
# (495198, 'N')
# (495532, 'N')
# (495869, 'N')
# (496171, 'N')
# (496478, 'N')
# (496797, 'N')
# (497137, 'N')
# (497479, 'N')
# (497813, 'N')
# (498150, 'N')
# (498470, 'N')
# (498791, 'N')
# (499119, 'N')
# (499452, 'N')
# (499785, 'N')
# (500105, 'N')
# (500414, 'N')
# (500737, 'N')
# (501064, 'N')
# (501403, 'N')
# (501751, 'N')
# (502080, 'N')
# (502418, 'N')
# (502727, 'N')
# (503077, 'N')
# (503428, 'N')
# (503764, 'N')
# (504126, 'N')
# (504476, 'N')
# (504812, 'N')
# (505135, 'N')
# (505491, 'N')
# (505835, 'N')
# (506185, 'N')
# (506546, 'N')
# (506863, 'N')
# (507200, 'N')
# (507561, 'N')
# (507933, 'N')
# (508266, 'N')
# (508626, 'N')
# (508968, 'N')
# (509292, 'N')
# (509631, 'N')
# (509803, 'V')
# (510333, 'N')
# (510679, 'N')
# (510991, 'N')
# (511324, 'N')
# (511676, 'N')
# (512001, 'N')
# (512352, 'N')
# (512727, 'N')
# (513055, 'N')
# (513396, 'N')
# (513728, 'N')
# (514108, 'N')
# (514463, 'N')
# (514835, 'N')
# (515187, 'N')
# (515523, 'N')
# (515873, 'N')
# (516218, 'N')
# (516603, 'N')
# (516974, 'N')
# (517322, 'N')
# (517664, 'N')
# (518023, 'N')
# (518366, 'N')
# (518747, 'N')
# (519098, 'N')
# (519439, 'N')
# (519775, 'N')
# (520138, 'N')
# (520456, 'N')
# (520800, 'N')
# (521184, 'N')
# (521516, 'N')
# (521877, 'N')
# (522231, 'N')
# (522562, 'N')
# (522979, 'N')
# (523357, 'N')
# (523728, 'N')
# (524098, 'N')
# (524460, 'N')
# (524803, 'N')
# (525182, 'N')
# (525529, 'N')
# (525899, 'N')
# (526230, 'N')
# (526417, 'V')
# (526532, 'x')
# (526953, 'N')
# (527326, 'N')
# (527651, 'N')
# (528026, 'N')
# (528246, 'A')
# (528756, 'N')
# (528960, 'A')
# (529389, 'N')
# (529762, 'N')
# (530114, 'N')
# (530468, 'N')
# (530823, 'N')
# (531143, 'N')
# (531533, 'N')
# (531896, 'N')
# (532241, 'N')
# (532611, 'N')
# (532972, 'N')
# (533340, 'N')
# (533697, 'N')
# (534071, 'N')
# (534441, 'N')
# (534807, 'N')
# (535166, 'N')
# (535512, 'N')
# (535879, 'N')
# (536232, 'N')
# (536601, 'N')
# (536964, 'N')
# (537294, 'N')
# (537648, 'N')
# (538021, 'N')
# (538380, 'N')
# (538765, 'N')
# (539114, 'N')
# (539457, 'N')
# (539790, 'N')
# (540147, 'N')
# (540510, 'N')
# (540890, 'N')
# (541222, 'N')
# (541571, 'N')
# (541916, 'N')
# (542276, 'N')
# (542626, 'N')
# (543000, 'N')
# (543367, 'N')
# (543711, 'N')
# (544088, 'N')
# (544465, 'N')
# (544832, 'N')
# (545213, 'N')
# (545549, 'N')
# (545915, 'N')
# (546280, 'N')
# (546682, 'N')
# (547029, 'N')
# (547409, 'N')
# (547749, 'N')
# (548115, 'N')
# (548462, 'N')
# (548885, 'N')
# (549273, 'N')
# (549655, 'N')
# (550042, 'N')
# (550402, 'N')
# (550751, 'N')
# (551170, 'N')
# (551539, 'N')
# (551902, 'N')
# (552291, 'N')
# (552634, 'N')
# (553104, 'N')
# (553575, 'N')
# (553977, 'N')
# (554330, 'N')
# (554714, 'N')
# (555088, 'N')
# (555466, 'N')
# (555864, 'N')
# (556210, 'N')
# (556575, 'N')
# (557011, 'N')
# (557470, 'N')
# (557884, 'N')
# (558302, 'N')
# (558669, 'N')
# (559052, 'N')
# (559414, 'N')
# (559847, 'N')
# (560237, 'N')
# (560625, 'N')
# (560993, 'N')
# (561362, 'N')
# (561739, 'N')
# (562157, 'N')
# (562558, 'N')
# (562950, 'N')
# (563317, 'N')
# (563706, 'N')
# (564086, 'N')
# (564468, 'N')
# (564846, 'N')
# (565212, 'N')
# (565572, 'N')
# (565952, 'N')
# (566307, 'N')
# (566674, 'N')
# (567036, 'N')
# (567385, 'N')
# (567752, 'N')
# (568109, 'N')
# (568546, 'N')
# (568978, 'N')
# (569337, 'N')
# (569722, 'N')
# (570095, 'N')
# (570447, 'N')
# (570835, 'N')
# (571175, 'N')
# (571508, 'N')
# (571906, 'N')
# (572235, 'N')
# (572662, 'N')
# (573037, 'N')
# (573369, 'N')
# (573730, 'N')
# (574067, 'N')
# (574405, 'N')
# (574779, 'N')
# (575185, 'N')
# (575525, 'N')
# (575908, 'N')
# (576278, 'N')
# (576620, 'N')
# (577020, 'N')
# (577394, 'N')
# (577783, 'N')
# (578104, 'N')
# (578473, 'N')
# (578850, 'N')
# (579194, 'N')
# (579592, 'N')
# (579935, 'N')
# (580289, 'N')
# (580619, 'N')
# (580794, 'V')
# (580872, 'x')
# (581312, 'N')
# (581645, 'N')
# (581964, 'N')
# (582337, 'N')
# (582659, 'N')
# (582995, 'N')
# (583336, 'N')
# (583741, 'N')
# (584064, 'N')
# (584408, 'N')
# (584785, 'N')
# (585105, 'N')
# (585447, 'N')
# (585838, 'N')
# (586214, 'N')
# (586538, 'N')
# (586937, 'N')
# (587285, 'N')
# (587629, 'N')
# (588029, 'N')
# (588384, 'N')
# (588750, 'N')
# (589061, 'N')
# (589419, 'N')
# (589759, 'N')
# (590143, 'N')
# (590491, 'N')
# (590834, 'N')
# (591185, 'N')
# (591506, 'N')
# (591847, 'N')
# (592235, 'N')
# (592575, 'N')
# (592937, 'N')
# (593280, 'N')
# (593635, 'N')
# (593996, 'N')
# (594339, 'N')
# (594463, '~')
# (594727, 'N')
# (595069, 'N')
# (595416, 'N')
# (595738, 'N')
# (596080, 'N')
# (596451, 'N')
# (596808, 'N')
# (597158, 'N')
# (597492, 'N')
# (597824, 'N')
# (598188, 'N')
# (598546, 'N')
# (598898, 'N')
# (599094, '|')
# (599288, 'N')
# (599637, 'N')
# (599997, 'N')
# (600358, 'N')
# (600745, 'N')
# (601109, 'N')
# (601485, 'N')
# (601827, 'N')
# (602172, 'N')
# (602530, 'N')
# (602910, 'N')
# (603275, 'N')
# (603629, 'N')
# (603976, 'N')
# (604307, 'N')
# (604655, 'N')
# (605019, 'N')
# (605387, 'N')
# (605745, 'N')
# (606080, 'N')
# (606422, 'N')
# (606753, 'N')
# (607101, 'N')
# (607453, 'N')
# (607799, 'N')
# (608121, 'N')
# (608439, 'N')
# (608757, 'N')
# (609074, 'N')
# (609401, 'N')
# (609738, 'N')
# (610069, 'N')
# (610380, 'N')
# (610683, 'N')
# (611005, 'N')
# (611323, 'N')
# (611647, 'N')
# (611968, 'N')
# (612283, 'N')
# (612590, 'N')
# (612888, 'N')
# (613186, 'N')
# (613500, 'N')
# (613811, 'N')
# (614116, 'N')
# (614419, 'N')
# (614720, 'N')
# (615018, 'N')
# (615317, 'N')
# (615630, 'N')
# (615960, 'N')
# (616278, 'N')
# (616601, 'N')
# (616909, 'N')
# (617224, 'N')
# (617531, 'N')
# (617841, 'N')
# (618169, 'N')
# (618482, 'N')
# (618779, 'N')
# (619062, 'N')
# (619235, 'V')
# (619299, 'x')
# (619643, 'N')
# (619930, 'N')
# (620228, 'N')
# (620536, 'N')
# (620829, 'N')
# (621112, 'N')
# (621389, 'N')
# (621668, 'N')
# (621962, 'N')
# (622255, 'N')
# (622550, 'N')
# (622863, 'N')
# (623156, 'N')
# (623439, 'N')
# (623726, 'N')
# (624015, 'N')
# (624322, 'N')
# (624633, 'N')
# (624933, 'N')
# (625241, 'N')
# (625534, 'N')
# (625814, 'N')
# (626105, 'N')
# (626397, 'N')
# (626715, 'N')
# (627019, 'N')
# (627320, 'N')
# (627624, 'N')
# (627914, 'N')
# (628196, 'N')
# (628492, 'N')
# (628795, 'N')
# (629108, 'N')
# (629414, 'N')
# (629711, 'N')
# (630011, 'N')
# (630306, 'N')
# (630605, 'N')
# (630910, 'N')
# (631218, 'N')
# (631433, 'A')
# (631840, 'N')
# (632124, 'N')
# (632428, 'N')
# (632729, 'N')
# (632876, '~')
# (633033, 'N')
# (633343, 'N')
# (633654, 'N')
# (633966, 'N')
# (634259, 'N')
# (634546, 'N')
# (634851, 'N')
# (635157, 'N')
# (635470, 'N')
# (635783, 'N')
# (636091, 'N')
# (636397, 'N')
# (636694, 'N')
# (636996, 'N')
# (637317, 'N')
# (637637, 'N')
# (637953, 'N')
# (638272, 'N')
# (638573, 'N')
# (638884, 'N')
# (639185, 'N')
# (639501, 'N')
# (639836, 'N')
# (640165, 'N')
# (640467, 'N')
# (640770, 'N')
# (641080, 'N')
# (641406, 'N')
# (641487, '~')
# (641744, 'N')
# (642096, 'N')
# (642449, 'N')
# (642770, 'N')
# (643089, 'N')
# (643416, 'N')
# (643743, 'N')
# (644072, 'N')
# (644411, 'N')
# (644733, 'N')
# (645034, 'N')
# (645328, 'N')
# (645618, 'N')
# (645952, 'N')
# (646271, 'N')
# (646463, '~')
# (646593, 'N')
# (646924, 'N')
# (647241, 'N')
# (647549, 'N')
# (647864, 'N')
# (648199, 'N')
# (648531, 'N')
# (648853, 'N')
# (649170, 'N')
# (649471, 'N')
# (649769, 'N')
# Canal 0
# Canal 1
# [[-0.78  -0.735]
#  [-0.78  -0.735]
#  [-0.78  -0.735]
#  ...,
#  [-1.02  -0.58 ]
#  [-1.04  -0.585]
#  [-1.28   0.   ]]
# (17, '+')
# (93, 'N')
# (326, 'N')
# (561, 'N')
# (798, 'N')
# (1017, 'N')
# (1253, 'N')
# (1488, 'N')
# (1730, 'N')
# (1967, 'N')
# (2208, 'N')
# (2448, 'N')
# (2692, 'N')
# (2935, 'N')
# (3184, 'N')
# (3435, 'N')
# (3686, 'N')
# (3935, 'N')
# (4182, 'N')
# (4427, 'N')
# (4682, 'N')
# (4933, 'N')
# (5183, 'N')
# (5425, 'N')
# (5678, 'N')
# (5929, 'N')
# (6178, 'N')
# (6417, 'N')
# (6680, 'N')
# (6926, 'N')
# (7164, 'N')
# (7406, 'N')
# (7659, 'N')
# (7904, 'N')
# (8149, 'N')
# (8377, 'N')
# (8618, 'N')
# (8860, 'N')
# (9097, 'N')
# (9332, 'N')
# (9571, 'N')
# (9817, 'N')
# (10058, 'N')
# (10298, 'N')
# (10534, 'N')
# (10786, 'N')
# (11033, 'N')
# (11278, 'N')
# (11528, 'N')
# (11778, 'N')
# (12030, 'N')
# (12280, 'N')
# (12538, 'N')
# (12793, 'N')
# (13045, 'N')
# (13295, 'N')
# (13553, 'N')
# (13805, 'N')
# (14055, 'N')
# (14301, 'N')
# (14554, 'N')
# (14804, 'N')
# (15052, 'N')
# (15305, 'N')
# (15560, 'N')
# (15810, 'N')
# (16060, 'N')
# (16310, 'N')
# (16564, 'N')
# (16819, 'N')
# (17073, 'N')
# (17319, 'N')
# (17572, 'N')
# (17826, 'N')
# (18079, 'N')
# (18334, 'N')
# (18596, 'N')
# (18857, 'N')
# (19112, 'N')
# (19358, 'N')
# (19630, 'N')
# (19884, 'N')
# (20145, 'N')
# (20400, 'N')
# (20662, 'N')
# (20905, 'N')
# (21164, 'N')
# (21420, 'N')
# (21676, 'N')
# (21913, 'N')
# (22157, 'N')
# (22406, 'N')
# (22658, 'N')
# (22902, 'N')
# (23144, 'N')
# (23380, 'N')
# (23634, 'N')
# (23879, 'N')
# (24129, 'N')
# (24376, 'N')
# (24625, 'N')
# (24875, 'N')
# (25125, 'N')
# (25376, 'N')
# (25632, 'N')
# (25879, 'N')
# (26128, 'N')
# (26374, 'N')
# (26625, 'N')
# (26871, 'N')
# (27113, 'N')
# (27360, 'N')
# (27612, 'N')
# (27858, 'N')
# (28106, 'N')
# (28360, 'N')
# (28614, 'N')
# (28868, 'N')
# (29122, 'N')
# (29378, 'N')
# (29632, 'N')
# (29889, 'N')
# (30145, 'N')
# (30403, 'N')
# (30659, 'N')
# (30902, 'N')
# (31149, 'N')
# (31402, 'N')
# (31653, 'N')
# (31904, 'N')
# (32140, 'N')
# (32386, 'N')
# (32640, 'N')
# (32888, 'N')
# (33139, 'N')
# (33394, 'N')
# (33636, 'N')
# (33887, 'N')
# (34136, 'N')
# (34392, 'N')
# (34631, 'N')
# (34872, 'N')
# (35112, 'N')
# (35361, 'N')
# (35601, 'N')
# (35842, 'N')
# (36076, 'N')
# (36315, 'N')
# (36565, 'N')
# (36808, 'N')
# (37055, 'N')
# (37307, 'N')
# (37556, 'N')
# (37800, 'N')
# (38049, 'N')
# (38302, 'N')
# (38552, 'N')
# (38804, 'N')
# (39057, 'N')
# (39323, 'N')
# (39582, 'N')
# (39840, 'N')
# (40096, 'N')
# (40359, 'N')
# (40613, 'N')
# (40873, 'N')
# (41128, 'N')
# (41391, 'N')
# (41645, 'N')
# (41904, 'N')
# (42161, 'N')
# (42419, 'N')
# (42675, 'N')
# (42931, 'N')
# (43195, 'N')
# (43454, 'N')
# (43713, 'N')
# (43967, 'N')
# (44234, 'N')
# (44501, 'N')
# (44775, 'N')
# (45042, 'N')
# (45309, 'N')
# (45575, 'N')
# (45836, 'N')
# (46102, 'N')
# (46364, 'N')
# (46621, 'N')
# (46873, 'N')
# (47135, 'N')
# (47392, 'N')
# (47644, 'N')
# (47895, 'N')
# (48157, 'N')
# (48408, 'N')
# (48659, 'N')
# (48907, 'N')
# (49161, 'N')
# (49406, 'N')
# (49660, 'N')
# (49905, 'N')
# (50157, 'N')
# (50403, 'N')
# (50646, 'N')
# (50899, 'N')
# (51151, 'N')
# (51400, 'N')
# (51643, 'N')
# (51883, 'N')
# (52138, 'N')
# (52383, 'N')
# (52628, 'N')
# (52867, 'N')
# (53114, 'N')
# (53350, 'N')
# (53596, 'N')
# (53844, 'N')
# (54095, 'N')
# (54342, 'N')
# (54586, 'N')
# (54837, 'N')
# (55094, 'N')
# (55342, 'N')
# (55594, 'N')
# (55836, 'N')
# (56083, 'N')
# (56329, 'N')
# (56577, 'N')
# (56828, 'N')
# (57082, 'N')
# (57333, 'N')
# (57585, 'N')
# (57841, 'N')
# (58109, 'N')
# (58372, 'N')
# (58635, 'N')
# (58891, 'N')
# (59161, 'N')
# (59427, 'N')
# (59697, 'N')
# (59971, 'N')
# (60236, 'N')
# (60492, 'N')
# (60750, 'N')
# (61016, 'N')
# (61275, 'N')
# (61534, 'N')
# (61783, 'N')
# (62056, 'N')
# (62322, 'N')
# (62591, 'N')
# (62861, 'N')
# (63125, 'N')
# (63385, 'N')
# (63647, 'N')
# (63913, 'N')
# (64182, 'N')
# (64454, 'N')
# (64724, 'N')
# (65006, 'N')
# (65298, 'N')
# (65598, 'N')
# (65910, 'N')
# (66227, 'N')
# (66536, 'N')
# (66861, 'N')
# (67190, 'N')
# (67502, 'N')
# (67805, 'N')
# (68106, 'N')
# (68394, 'N')
# (68674, 'N')
# (68951, 'N')
# (69226, 'N')
# (69502, 'N')
# (69769, 'N')
# (70039, 'N')
# (70305, 'N')
# (70573, 'N')
# (70837, 'N')
# (71104, 'N')
# (71359, 'N')
# (71617, 'N')
# (71878, 'N')
# (72138, 'N')
# (72393, 'N')
# (72642, 'N')
# (72896, 'N')
# (73148, 'N')
# (73402, 'N')
# (73647, 'N')
# (73904, 'N')
# (74148, 'N')
# (74394, 'N')
# (74645, 'N')
# (74899, 'N')
# (75146, 'N')
# (75394, 'N')
# (75638, 'N')
# (75893, 'N')
# (76138, 'N')
# (76391, 'N')
# (76630, 'N')
# (76877, 'N')
# (77123, 'N')
# (77370, 'N')
# (77618, 'N')
# (77873, 'N')
# (78117, 'N')
# (78366, 'N')
# (78611, 'N')
# (78872, 'N')
# (79123, 'N')
# (79379, 'N')
# (79630, 'N')
# (79891, 'N')
# (80150, 'N')
# (80409, 'N')
# (80672, 'N')
# (80930, 'N')
# (81184, 'N')
# (81438, 'N')
# (81701, 'N')
# (81954, 'N')
# (82213, 'N')
# (82462, 'N')
# (82719, 'N')
# (82969, 'N')
# (83220, 'N')
# (83474, 'N')
# (83731, 'N')
# (83978, 'N')
# (84227, 'N')
# (84475, 'N')
# (84732, 'N')
# (84982, 'N')
# (85236, 'N')
# (85480, 'N')
# (85736, 'N')
# (85990, 'N')
# (86243, 'N')
# (86502, 'N')
# (86759, 'N')
# (87012, 'N')
# (87260, 'N')
# (87520, 'N')
# (87779, 'N')
# (88036, 'N')
# (88287, 'N')
# (88546, 'N')
# (88802, 'N')
# (89059, 'N')
# (89318, 'N')
# (89582, 'N')
# (89842, 'N')
# (90105, 'N')
# (90370, 'N')
# (90639, 'N')
# (90900, 'N')
# (91167, 'N')
# (91428, 'N')
# (91693, 'N')
# (91953, 'N')
# (92212, 'N')
# (92473, 'N')
# (92737, 'N')
# (92996, 'N')
# (93252, 'N')
# (93519, 'N')
# (93784, 'N')
# (94049, 'N')
# (94311, 'N')
# (94584, 'N')
# (94847, 'N')
# (95117, 'N')
# (95389, 'N')
# (95664, 'N')
# (95929, 'N')
# (96195, 'N')
# (96465, 'N')
# (96727, 'N')
# (96992, 'N')
# (97247, 'N')
# (97506, 'N')
# (97762, 'N')
# (98026, 'N')
# (98285, 'N')
# (98547, 'N')
# (98800, 'N')
# (99056, 'N')
# (99310, 'N')
# (99578, 'N')
# (99833, 'N')
# (100087, 'N')
# (100339, 'N')
# (100597, 'N')
# (100849, 'N')
# (101098, 'N')
# (101353, 'N')
# (101604, 'N')
# (101857, 'N')
# (102117, 'N')
# (102392, 'N')
# (102672, 'N')
# (102967, 'N')
# (103257, 'N')
# (103552, 'N')
# (103834, 'N')
# (104122, 'N')
# (104406, 'N')
# (104686, 'N')
# (104956, 'N')
# (105223, 'N')
# (105502, 'N')
# (105775, 'N')
# (106047, 'N')
# (106310, 'N')
# (106590, 'N')
# (106867, 'N')
# (107144, 'N')
# (107425, 'N')
# (107702, 'N')
# (107973, 'N')
# (108246, 'N')
# (108519, 'N')
# (108779, 'N')
# (109046, 'N')
# (109306, 'N')
# (109573, 'N')
# (109839, 'N')
# (110111, 'N')
# (110387, 'N')
# (110664, 'N')
# (110937, 'N')
# (111205, 'N')
# (111488, 'N')
# (111763, 'N')
# (112031, 'N')
# (112292, 'N')
# (112560, 'N')
# (112826, 'N')
# (113090, 'N')
# (113358, 'N')
# (113613, 'N')
# (113870, 'N')
# (114125, 'N')
# (114393, 'N')
# (114645, 'N')
# (114897, 'N')
# (115145, 'N')
# (115403, 'N')
# (115650, 'N')
